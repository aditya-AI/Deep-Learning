# %%
#create word2vectors from a dataset and analyze them to see a semantic similarity.
#my corpus was really small just a book with 79000 tokens, but I would recommend using Game of thrones or any other book which has a bigger corpus for better results.

# %%
#future is the missing compatibility layer between Python 2 and Python 3. 
#It allows you to use a single, clean Python 3.x-compatible codebase to 
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function

# %%
#used for encoding words to vectors
import codecs
#finds all pathnames matching a pattern, like regex and it helps in searching through a large dataset in a faster way.
import glob
#log events for libraries
import logging
#used for concurrency, running multiple threads and having each thread run a different process, which makes the program run faster.
#one major reason is for eg: you have 4 cores in your CPU and you program uses only 1 core which slows down your processing, but by using Multiprocessing it divides the code in to all the 4 CPU to make processing faster.
import multiprocessing
#dealing with operating system , like a reading file, saving it or loading it after training the model.
import os
#used for pretty printing, human readable form
import pprint
#granular regular expressions
import re

# %%
# %matplotlib inline

# %%
#natural language toolkit, if you have a sentence and you feed it in nltk, it will give you tokens for each word
#you can have part of speech tagging like is the word a noun, verb, adjective, pronoun etc.
import nltk
#word 2 vec library, created by google, its a generalised collection of words
import gensim.models.word2vec as w2v
#dimensionality reduction, suppose we have word vectors that is going to be multidimensional, like I have used 250 Dimensional word vectors
#this helps in converting it in to 2D, to visualize them in a 2D graph.
import sklearn.manifold
##imports numpy as np. Numpy is used for basic matrix multiplication, addition. 
import numpy as np
#plotting
import matplotlib.pyplot as plt
#for parsing the dataset
import pandas as pd
#for visualization of the dataset, mainly used while plotting the graph
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Step 1: Process our data
#clean data, punkt is a pretrained tokeniser which tokenises our text
nltk.download("punkt")
#words like (and,the,an a) are removed from the corpus so that the vectors are more accurate. 
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/adityasharma101993/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/adityasharma101993/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#gets all the book names matching the txt file
book_filenames = sorted(glob.glob("./*.txt"))

# %%
#print books
print("Found books:")
book_filenames
# Out:
# Found books:
# ['./J. D. Vance-Hillbilly Elegy-HarperCollins (2016).txt']

# %%
#initialize rawunicode , we'll add all text to this one big file in memory
corpus_raw = u""
#for each book, read it, open it in utf 8 format, utf 8 is the format reading from files and unicode for vectors
#add it to the raw corpus
#corpus raw is a unicode format and we want to convert it in UTF-8.
#codecs library reads book file format and make it in UTF readable format.
for book_filename in book_filenames:
    book_filename = book_filename.decode('unicode_escape').encode('UTF-8')
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "UTF-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading './J. D. Vance-Hillbilly Elegy-HarperCollins (2016).txt'...
# Corpus is now 444038 characters long

# %%
#tokenizastion, saved the trained model here
#load nltk punk in to memory its a trained model loaded in a byte stream (pickle:file format which loads as a byte stream)
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer

# %%
#tokenize into sentences
#tokenizer is pre trained that converts words in to tokens and type of tokens we want is sentences.
raw_sentences = tokenizer.tokenize(corpus_raw)
#raw_sentences

# %%
#convert sentences into list of words
#remove unecessary characters, split into words, no hyphens
#split into words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#for each sentence we have initialize an empty sentence list and add sentences to it, sentences where each word is tokenized.
#we add all the words in the empty sentence list by calling the sentence_to_wordlist function we defined above and by passing the raw_sentences which are then cleaned and appended in to sentence list.
#we check if our raw_sentence is greater than zero or not which is self explanatory.
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
#print an example
print(raw_sentences[9])
print(sentence_to_wordlist(raw_sentences[9]))
# Out:
# So I didn’t write this book because I’ve accomplished something extraordinary.
# [u'So', u'I', u'didn', u't', u'write', u'this', u'book', u'because', u'I', u've', u'accomplished', u'something', u'extraordinary']

# %%
#count tokens, each one being a sentence
#here we just calculate the sentences and store the count in token_count and print it.
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
token_count
#for sentence in sentences:
#    print(sentence)
# Out:
# The book corpus contains 79,767 tokens
# 79767

# %%
#step 2 build our model, another one is Glove
#set of words can be generalised in to a set of vectors like masculine, bob, john, beard, moustache all belong to man category
# here we define hyperparameters for our model.
#we convert words in to vectors and create vectors of these vectors.
#once we have the vectors we can use them for 3 main tasks like Similarity, distance and Ranking (Like browse all scientific papers and rank them based on papers that have word "Dropout" maximum numbers of time).


# Dimensionality of the resulting word vectors.
#more dimensions mean more training time, more computationally complex, but more generalized and more accurate. 
num_features = 250

# Minimum word count threshold, smallest set of words we want to recognise when we convert words to vectors
min_word_count = 3

# Number of threads to run in parallel, more workers faster to train.
num_workers = multiprocessing.cpu_count()

# Context window length, size of what we are looking at a time or blocks of words we consider at a time.
context_size = 7

# Downsample setting for frequent words that we do not want our model to look at it again and again.
#rate 0 and 1e-5 is recommended.
#how often to use
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#It is a random generator which tells which part of the words to convert in to vectors.
# Seeds makes sure our model is deterministic and its good for for debugging.
seed = 1

# %%
#we use gensim library topic modelling, you give it a corpus like this and it will create a model, save it, load it and given some words that we in the corpus it will give how similar the words are and what does not match.
vance2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

vance2vec.build_vocab(sentences) # number of words in corpus after downsampling, loads corpus that we clean in to memory and print size of it.

vance2vec.train(sentences, total_examples=vance2vec.corpus_count, epochs=vance2vec.iter)
# Out:
# 269094

# %%
print("Word2Vec vocabulary length:", len( vance2vec.wv.vocab))
vance2vec.wv.vocab
# Out:
# Word2Vec vocabulary length: 2937
# {u'Preble': <gensim.models.keyedvectors.Vocab at 0x7f6244467d10>,
#  u'resist': <gensim.models.keyedvectors.Vocab at 0x7f6244434290>,
#  u'yellow': <gensim.models.keyedvectors.Vocab at 0x7f6244f13b50>,
#  u'four': <gensim.models.keyedvectors.Vocab at 0x7f6244afbfd0>,
#  u'sleep': <gensim.models.keyedvectors.Vocab at 0x7f6244429890>,
#  u'hanging': <gensim.models.keyedvectors.Vocab at 0x7f624457b690>,
#  u'mansion': <gensim.models.keyedvectors.Vocab at 0x7f62444ab650>,
#  u'oldest': <gensim.models.keyedvectors.Vocab at 0x7f62444ab690>,
#  u'saved': <gensim.models.keyedvectors.Vocab at 0x7f62444ab6d0>,
#  u'Until': <gensim.models.keyedvectors.Vocab at 0x7f624457b790>,
#  u'forget': <gensim.models.keyedvectors.Vocab at 0x7f624440e310>,
#  u'relationships': <gensim.models.keyedvectors.Vocab at 0x7f62444ab710>,
#  u'whose': <gensim.models.keyedvectors.Vocab at 0x7f6244467d90>,
#  u'feeding': <gensim.models.keyedvectors.Vocab at 0x7f6244429950>,
#  u'buddy': <gensim.models.keyedvectors.Vocab at 0x7f6244467dd0>,
#  u'poorest': <gensim.models.keyedvectors.Vocab at 0x7f6244429990>,
#  u'presents': <gensim.models.keyedvectors.Vocab at 0x7f6244467e10>,
#  u'under': <gensim.models.keyedvectors.Vocab at 0x7f62444299d0>,
#  u'teaching': <gensim.models.keyedvectors.Vocab at 0x7f6244467e50>,
#  u'sped': <gensim.models.keyedvectors.Vocab at 0x7f62444ab750>,
#  u'pride': <gensim.models.keyedvectors.Vocab at 0x7f6244429a10>,
#  u'worth': <gensim.models.keyedvectors.Vocab at 0x7f62444ab790>,
#  u'League': <gensim.models.keyedvectors.Vocab at 0x7f62444ab7d0>,
#  u'regional': <gensim.models.keyedvectors.Vocab at 0x7f624457b810>,
#  u'smack': <gensim.models.keyedvectors.Vocab at 0x7f6244467ed0>,
#  u'every': <gensim.models.keyedvectors.Vocab at 0x7f6244429a90>,
#  u'affect': <gensim.models.keyedvectors.Vocab at 0x7f6244467f10>,
#  u'screaming': <gensim.models.keyedvectors.Vocab at 0x7f624457b850>,
#  u'school': <gensim.models.keyedvectors.Vocab at 0x7f6244429ad0>,
#  u'called': <gensim.models.keyedvectors.Vocab at 0x7f62443db4d0>,
#  u'companies': <gensim.models.keyedvectors.Vocab at 0x7f6244467f50>,
#  u'announced': <gensim.models.keyedvectors.Vocab at 0x7f624445c5d0>,
#  u'Go': <gensim.models.keyedvectors.Vocab at 0x7f6244429b10>,
#  u'heading': <gensim.models.keyedvectors.Vocab at 0x7f6244467f90>,
#  u'triumph': <gensim.models.keyedvectors.Vocab at 0x7f62444ab810>,
#  u'clothes': <gensim.models.keyedvectors.Vocab at 0x7f6244467fd0>,
#  u'force': <gensim.models.keyedvectors.Vocab at 0x7f624446d050>,
#  u'phones': <gensim.models.keyedvectors.Vocab at 0x7f62444ab850>,
#  u'surrounding': <gensim.models.keyedvectors.Vocab at 0x7f6244429b50>,
#  u'second': <gensim.models.keyedvectors.Vocab at 0x7f624457b8d0>,
#  u'street': <gensim.models.keyedvectors.Vocab at 0x7f6244429b90>,
#  u'theory': <gensim.models.keyedvectors.Vocab at 0x7f624443f910>,
#  u'even': <gensim.models.keyedvectors.Vocab at 0x7f624446d0d0>,
#  u'Eventually': <gensim.models.keyedvectors.Vocab at 0x7f624446d110>,
#  u'captain': <gensim.models.keyedvectors.Vocab at 0x7f6244467d50>,
#  u'hide': <gensim.models.keyedvectors.Vocab at 0x7f6244429c10>,
#  u'hate': <gensim.models.keyedvectors.Vocab at 0x7f62444298d0>,
#  u'contributed': <gensim.models.keyedvectors.Vocab at 0x7f624457b910>,
#  u'weren': <gensim.models.keyedvectors.Vocab at 0x7f6244434850>,
#  u'Hamilton': <gensim.models.keyedvectors.Vocab at 0x7f624457b950>,
#  u'above': <gensim.models.keyedvectors.Vocab at 0x7f62444ab890>,
#  u'retrieved': <gensim.models.keyedvectors.Vocab at 0x7f62444ff750>,
#  u'churches': <gensim.models.keyedvectors.Vocab at 0x7f62444ab8d0>,
#  u'struggled': <gensim.models.keyedvectors.Vocab at 0x7f62443e0110>,
#  u'poorly': <gensim.models.keyedvectors.Vocab at 0x7f6244429910>,
#  u'ever': <gensim.models.keyedvectors.Vocab at 0x7f624446d190>,
#  u'told': <gensim.models.keyedvectors.Vocab at 0x7f62444ab910>,
#  u'Sometimes': <gensim.models.keyedvectors.Vocab at 0x7f6244483690>,
#  u'never': <gensim.models.keyedvectors.Vocab at 0x7f62444f4290>,
#  u'here': <gensim.models.keyedvectors.Vocab at 0x7f624457b9d0>,
#  u'hundreds': <gensim.models.keyedvectors.Vocab at 0x7f6244429cd0>,
#  u'remarried': <gensim.models.keyedvectors.Vocab at 0x7f62444ab950>,
#  u'reported': <gensim.models.keyedvectors.Vocab at 0x7f624457ba10>,
#  u'hers': <gensim.models.keyedvectors.Vocab at 0x7f624457ba50>,
#  u'Ohio': <gensim.models.keyedvectors.Vocab at 0x7f624446d2d0>,
#  u'dry': <gensim.models.keyedvectors.Vocab at 0x7f624446d310>,
#  u'kids': <gensim.models.keyedvectors.Vocab at 0x7f624457ba90>,
#  u'daughter': <gensim.models.keyedvectors.Vocab at 0x7f62444ab990>,
#  u'employees': <gensim.models.keyedvectors.Vocab at 0x7f62444ab9d0>,
#  u'changed': <gensim.models.keyedvectors.Vocab at 0x7f6244429d50>,
#  u'jail': <gensim.models.keyedvectors.Vocab at 0x7f6244483090>,
#  u'credit': <gensim.models.keyedvectors.Vocab at 0x7f624446d350>,
#  u'military': <gensim.models.keyedvectors.Vocab at 0x7f624457bad0>,
#  u'settled': <gensim.models.keyedvectors.Vocab at 0x7f6244429d90>,
#  u'criticism': <gensim.models.keyedvectors.Vocab at 0x7f624457bb10>,
#  u'pessimistic': <gensim.models.keyedvectors.Vocab at 0x7f62444aba10>,
#  u'fantastic': <gensim.models.keyedvectors.Vocab at 0x7f624446d3d0>,
#  u'mobility': <gensim.models.keyedvectors.Vocab at 0x7f624446d410>,
#  u'explained': <gensim.models.keyedvectors.Vocab at 0x7f624457bb50>,
#  u'objectively': <gensim.models.keyedvectors.Vocab at 0x7f624446d450>,
#  u'brought': <gensim.models.keyedvectors.Vocab at 0x7f62444f4cd0>,
#  u'patience': <gensim.models.keyedvectors.Vocab at 0x7f6244429e10>,
#  u'moral': <gensim.models.keyedvectors.Vocab at 0x7f624446d4d0>,
#  u'opportunities': <gensim.models.keyedvectors.Vocab at 0x7f62443caad0>,
#  u'hindsight': <gensim.models.keyedvectors.Vocab at 0x7f6244478b10>,
#  u'total': <gensim.models.keyedvectors.Vocab at 0x7f62444aba90>,
#  u'unit': <gensim.models.keyedvectors.Vocab at 0x7f624457bb90>,
#  u'plot': <gensim.models.keyedvectors.Vocab at 0x7f62444abad0>,
#  u'spoke': <gensim.models.keyedvectors.Vocab at 0x7f624457bbd0>,
#  u'would': <gensim.models.keyedvectors.Vocab at 0x7f6244429e50>,
#  u'hospital': <gensim.models.keyedvectors.Vocab at 0x7f6244429e90>,
#  u'achieve': <gensim.models.keyedvectors.Vocab at 0x7f6244462610>,
#  u'arms': <gensim.models.keyedvectors.Vocab at 0x7f624446d510>,
#  u'insult': <gensim.models.keyedvectors.Vocab at 0x7f62444abb10>,
#  u'program': <gensim.models.keyedvectors.Vocab at 0x7f62443cab10>,
#  u'music': <gensim.models.keyedvectors.Vocab at 0x7f624457bc10>,
#  u'calm': <gensim.models.keyedvectors.Vocab at 0x7f624446d590>,
#  u'survive': <gensim.models.keyedvectors.Vocab at 0x7f624446d5d0>,
#  u'type': <gensim.models.keyedvectors.Vocab at 0x7f624446d610>,
#  u'until': <gensim.models.keyedvectors.Vocab at 0x7f624457bc50>,
#  u'separated': <gensim.models.keyedvectors.Vocab at 0x7f62444abb50>,
#  u'successful': <gensim.models.keyedvectors.Vocab at 0x7f624457bc90>,
#  u'wars': <gensim.models.keyedvectors.Vocab at 0x7f624446d690>,
#  u'hurt': <gensim.models.keyedvectors.Vocab at 0x7f624457bcd0>,
#  u'Kameron': <gensim.models.keyedvectors.Vocab at 0x7f624457bd10>,
#  u'glass': <gensim.models.keyedvectors.Vocab at 0x7f624457bd50>,
#  u'adult': <gensim.models.keyedvectors.Vocab at 0x7f624446d6d0>,
#  u'excellent': <gensim.models.keyedvectors.Vocab at 0x7f6244429f90>,
#  u'hold': <gensim.models.keyedvectors.Vocab at 0x7f624457bd90>,
#  u'sorry': <gensim.models.keyedvectors.Vocab at 0x7f6244467e90>,
#  u'mountains': <gensim.models.keyedvectors.Vocab at 0x7f62443db3d0>,
#  u'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f624457bdd0>,
#  u'me': <gensim.models.keyedvectors.Vocab at 0x7f624447d550>,
#  u'word': <gensim.models.keyedvectors.Vocab at 0x7f62444abbd0>,
#  u'wore': <gensim.models.keyedvectors.Vocab at 0x7f62444abc10>,
#  u'divorced': <gensim.models.keyedvectors.Vocab at 0x7f62444abc50>,
#  u'rights': <gensim.models.keyedvectors.Vocab at 0x7f624446d750>,
#  u'work': <gensim.models.keyedvectors.Vocab at 0x7f62444abc90>,
#  u'roof': <gensim.models.keyedvectors.Vocab at 0x7f624446d790>,
#  u'obstacle': <gensim.models.keyedvectors.Vocab at 0x7f62443d5b90>,
#  u'already': <gensim.models.keyedvectors.Vocab at 0x7f624442f910>,
#  u'my': <gensim.models.keyedvectors.Vocab at 0x7f624442f0d0>,
#  u'example': <gensim.models.keyedvectors.Vocab at 0x7f624457be10>,
#  u'estate': <gensim.models.keyedvectors.Vocab at 0x7f624442f110>,
#  u'give': <gensim.models.keyedvectors.Vocab at 0x7f624446d7d0>,
#  u'organized': <gensim.models.keyedvectors.Vocab at 0x7f624457be50>,
#  u'honey': <gensim.models.keyedvectors.Vocab at 0x7f624446d810>,
#  u'Brian': <gensim.models.keyedvectors.Vocab at 0x7f62444ff050>,
#  u'foods': <gensim.models.keyedvectors.Vocab at 0x7f624446d850>,
#  u'overheard': <gensim.models.keyedvectors.Vocab at 0x7f624442f150>,
#  u'Lori': <gensim.models.keyedvectors.Vocab at 0x7f624442f190>,
#  u'want': <gensim.models.keyedvectors.Vocab at 0x7f624457be90>,
#  u'times': <gensim.models.keyedvectors.Vocab at 0x7f624442f1d0>,
#  u'worse': <gensim.models.keyedvectors.Vocab at 0x7f62443cac50>,
#  u'end': <gensim.models.keyedvectors.Vocab at 0x7f624442f210>,
#  u'turn': <gensim.models.keyedvectors.Vocab at 0x7f624443f950>,
#  u'complaining': <gensim.models.keyedvectors.Vocab at 0x7f624457bed0>,
#  u'Journal': <gensim.models.keyedvectors.Vocab at 0x7f62444abd10>,
#  u'sitting': <gensim.models.keyedvectors.Vocab at 0x7f624442f250>,
#  u'damage': <gensim.models.keyedvectors.Vocab at 0x7f624457bf10>,
#  u'machine': <gensim.models.keyedvectors.Vocab at 0x7f624457bf50>,
#  u'how': <gensim.models.keyedvectors.Vocab at 0x7f624457bf90>,
#  u'interview': <gensim.models.keyedvectors.Vocab at 0x7f62444abd50>,
#  u'A': <gensim.models.keyedvectors.Vocab at 0x7f624457bfd0>,
#  u'credential': <gensim.models.keyedvectors.Vocab at 0x7f62444ee050>,
#  u'rise': <gensim.models.keyedvectors.Vocab at 0x7f6244429a50>,
#  u'beauty': <gensim.models.keyedvectors.Vocab at 0x7f62444ee090>,
#  u'mess': <gensim.models.keyedvectors.Vocab at 0x7f624442f2d0>,
#  u'ladder': <gensim.models.keyedvectors.Vocab at 0x7f62444abdd0>,
#  u'after': <gensim.models.keyedvectors.Vocab at 0x7f62444abe10>,
#  u'loyalty': <gensim.models.keyedvectors.Vocab at 0x7f624446d8d0>,
#  u'demanding': <gensim.models.keyedvectors.Vocab at 0x7f624442f310>,
#  u'wrong': <gensim.models.keyedvectors.Vocab at 0x7f62444ee0d0>,
#  u'lay': <gensim.models.keyedvectors.Vocab at 0x7f62444abe50>,
#  u'outbursts': <gensim.models.keyedvectors.Vocab at 0x7f62444abe90>,
#  u'president': <gensim.models.keyedvectors.Vocab at 0x7f624446d950>,
#  u'law': <gensim.models.keyedvectors.Vocab at 0x7f62444abed0>,
#  u'lap': <gensim.models.keyedvectors.Vocab at 0x7f62444abf10>,
#  u'types': <gensim.models.keyedvectors.Vocab at 0x7f62444ee110>,
#  u'purchase': <gensim.models.keyedvectors.Vocab at 0x7f624446d990>,
#  u'All': <gensim.models.keyedvectors.Vocab at 0x7f624446d9d0>,
#  u'third': <gensim.models.keyedvectors.Vocab at 0x7f624446da10>,
#  u'appreciate': <gensim.models.keyedvectors.Vocab at 0x7f62444abf50>,
#  u'Japanese': <gensim.models.keyedvectors.Vocab at 0x7f624442f390>,
#  u'childhood': <gensim.models.keyedvectors.Vocab at 0x7f624443fa10>,
#  u'cigarettes': <gensim.models.keyedvectors.Vocab at 0x7f6244484190>,
#  u'green': <gensim.models.keyedvectors.Vocab at 0x7f62444abf90>,
#  u'Another': <gensim.models.keyedvectors.Vocab at 0x7f62444ee150>,
#  u'aloud': <gensim.models.keyedvectors.Vocab at 0x7f6244483dd0>,
#  u'Blantons': <gensim.models.keyedvectors.Vocab at 0x7f624442f3d0>,
#  u'first': <gensim.models.keyedvectors.Vocab at 0x7f6244483850>,
#  u'order': <gensim.models.keyedvectors.Vocab at 0x7f62444abfd0>,
#  u'wine': <gensim.models.keyedvectors.Vocab at 0x7f62444ee190>,
#  u'Even': <gensim.models.keyedvectors.Vocab at 0x7f62444c1110>,
#  u'feedback': <gensim.models.keyedvectors.Vocab at 0x7f62444ee1d0>,
#  u'office': <gensim.models.keyedvectors.Vocab at 0x7f62444b0050>,
#  u'welcomed': <gensim.models.keyedvectors.Vocab at 0x7f62444ee210>,
#  u'dreamed': <gensim.models.keyedvectors.Vocab at 0x7f62444ee250>,
#  u'over': <gensim.models.keyedvectors.Vocab at 0x7f624442f410>,
#  u'fall': <gensim.models.keyedvectors.Vocab at 0x7f624440e450>,
#  u'thousands': <gensim.models.keyedvectors.Vocab at 0x7f62443e0bd0>,
#  u'before': <gensim.models.keyedvectors.Vocab at 0x7f624446da90>,
#  u'beside': <gensim.models.keyedvectors.Vocab at 0x7f6244434990>,
#  u'accent': <gensim.models.keyedvectors.Vocab at 0x7f62443e0790>,
#  u'His': <gensim.models.keyedvectors.Vocab at 0x7f62444ee290>,
#  u'fit': <gensim.models.keyedvectors.Vocab at 0x7f62444ee2d0>,
#  u'somewhere': <gensim.models.keyedvectors.Vocab at 0x7f62444b0090>,
#  u'fix': <gensim.models.keyedvectors.Vocab at 0x7f62444ee310>,
#  u'expectations': <gensim.models.keyedvectors.Vocab at 0x7f624442f490>,
#  u'Here': <gensim.models.keyedvectors.Vocab at 0x7f624442f4d0>,
#  u'crew': <gensim.models.keyedvectors.Vocab at 0x7f624446db10>,
#  u'better': <gensim.models.keyedvectors.Vocab at 0x7f624446db50>,
#  u'differently': <gensim.models.keyedvectors.Vocab at 0x7f624446db90>,
#  u'enlisted': <gensim.models.keyedvectors.Vocab at 0x7f624446dbd0>,
#  u'weeks': <gensim.models.keyedvectors.Vocab at 0x7f624446dc10>,
#  u'easier': <gensim.models.keyedvectors.Vocab at 0x7f62444ee350>,
#  u'overcome': <gensim.models.keyedvectors.Vocab at 0x7f624446dc50>,
#  u'Zeppelin': <gensim.models.keyedvectors.Vocab at 0x7f62444572d0>,
#  u'then': <gensim.models.keyedvectors.Vocab at 0x7f62444b00d0>,
#  u'them': <gensim.models.keyedvectors.Vocab at 0x7f62444b0110>,
#  u'affected': <gensim.models.keyedvectors.Vocab at 0x7f62444b0150>,
#  u'combination': <gensim.models.keyedvectors.Vocab at 0x7f624446dc90>,
#  u'safe': <gensim.models.keyedvectors.Vocab at 0x7f62444b0190>,
#  u'vouchers': <gensim.models.keyedvectors.Vocab at 0x7f6244484a90>,
#  u'Goldie': <gensim.models.keyedvectors.Vocab at 0x7f624442f590>,
#  u'break': <gensim.models.keyedvectors.Vocab at 0x7f62444b01d0>,
#  u'roommate': <gensim.models.keyedvectors.Vocab at 0x7f62444b0210>,
#  u'drinking': <gensim.models.keyedvectors.Vocab at 0x7f62443db990>,
#  u'they': <gensim.models.keyedvectors.Vocab at 0x7f62444b0250>,
#  u'schools': <gensim.models.keyedvectors.Vocab at 0x7f62444ee390>,
#  u'sixteen': <gensim.models.keyedvectors.Vocab at 0x7f6244484bd0>,
#  u'lifelong': <gensim.models.keyedvectors.Vocab at 0x7f62444b0290>,
#  u'bank': <gensim.models.keyedvectors.Vocab at 0x7f62444b02d0>,
#  u'rhetoric': <gensim.models.keyedvectors.Vocab at 0x7f624446dcd0>,
#  u'meat': <gensim.models.keyedvectors.Vocab at 0x7f624446dd10>,
#  u'regularly': <gensim.models.keyedvectors.Vocab at 0x7f62444247d0>,
#  u'Indeed': <gensim.models.keyedvectors.Vocab at 0x7f624446dd50>,
#  u'arrested': <gensim.models.keyedvectors.Vocab at 0x7f624446dd90>,
#  u'mistrust': <gensim.models.keyedvectors.Vocab at 0x7f624446ddd0>,
#  u'daughters': <gensim.models.keyedvectors.Vocab at 0x7f62443d5c90>,
#  u'reasonable': <gensim.models.keyedvectors.Vocab at 0x7f62444b0310>,
#  u'fitness': <gensim.models.keyedvectors.Vocab at 0x7f6244408c50>,
#  u'went': <gensim.models.keyedvectors.Vocab at 0x7f624446de50>,
#  u'meal': <gensim.models.keyedvectors.Vocab at 0x7f6244484f90>,
#  u'luck': <gensim.models.keyedvectors.Vocab at 0x7f624448a090>,
#  u'financial': <gensim.models.keyedvectors.Vocab at 0x7f62444ee3d0>,
#  u'series': <gensim.models.keyedvectors.Vocab at 0x7f62444ee410>,
#  u'crimes': <gensim.models.keyedvectors.Vocab at 0x7f62444b0350>,
#  u'Bonnie': <gensim.models.keyedvectors.Vocab at 0x7f62443cae10>,
#  u'taught': <gensim.models.keyedvectors.Vocab at 0x7f624446df10>,
#  u'forgot': <gensim.models.keyedvectors.Vocab at 0x7f624448a410>,
#  u'classmates': <gensim.models.keyedvectors.Vocab at 0x7f624446df90>,
#  u'disloyalty': <gensim.models.keyedvectors.Vocab at 0x7f62444b0390>,
#  u'network': <gensim.models.keyedvectors.Vocab at 0x7f62444b03d0>,
#  u'driving': <gensim.models.keyedvectors.Vocab at 0x7f624442f650>,
#  u'Huber': <gensim.models.keyedvectors.Vocab at 0x7f62444ee490>,
#  u'motel': <gensim.models.keyedvectors.Vocab at 0x7f624442f690>,
#  u'forty': <gensim.models.keyedvectors.Vocab at 0x7f62444b0410>,
#  u'content': <gensim.models.keyedvectors.Vocab at 0x7f624446dfd0>,
#  u're': <gensim.models.keyedvectors.Vocab at 0x7f62444ee4d0>,
#  u'laid': <gensim.models.keyedvectors.Vocab at 0x7f624442f6d0>,
#  u'revolving': <gensim.models.keyedvectors.Vocab at 0x7f624448a950>,
#  u'size': <gensim.models.keyedvectors.Vocab at 0x7f62444c1350>,
#  u'assured': <gensim.models.keyedvectors.Vocab at 0x7f62444ee550>,
#  u'written': <gensim.models.keyedvectors.Vocab at 0x7f62443c5150>,
#  u'University': <gensim.models.keyedvectors.Vocab at 0x7f62444ee590>,
#  u'threatened': <gensim.models.keyedvectors.Vocab at 0x7f62444ee5d0>,
#  u'given': <gensim.models.keyedvectors.Vocab at 0x7f624443fa90>,
#  u'free': <gensim.models.keyedvectors.Vocab at 0x7f624442f750>,
#  u'standard': <gensim.models.keyedvectors.Vocab at 0x7f62444b0450>,
#  u'struggle': <gensim.models.keyedvectors.Vocab at 0x7f6244472090>,
#  u'W': <gensim.models.keyedvectors.Vocab at 0x7f624442f790>,
#  u'biological': <gensim.models.keyedvectors.Vocab at 0x7f624440e4d0>,
#  u'wanted': <gensim.models.keyedvectors.Vocab at 0x7f624442f7d0>,
#  u'publication': <gensim.models.keyedvectors.Vocab at 0x7f624442f810>,
#  u'ate': <gensim.models.keyedvectors.Vocab at 0x7f62444ee650>,
#  u'Clinton': <gensim.models.keyedvectors.Vocab at 0x7f62444720d0>,
#  u'created': <gensim.models.keyedvectors.Vocab at 0x7f62444b0490>,
#  u'starts': <gensim.models.keyedvectors.Vocab at 0x7f6244472110>,
#  u'National': <gensim.models.keyedvectors.Vocab at 0x7f62444b04d0>,
#  u'days': <gensim.models.keyedvectors.Vocab at 0x7f624442f850>,
#  u'isn': <gensim.models.keyedvectors.Vocab at 0x7f6244472150>,
#  u'soda': <gensim.models.keyedvectors.Vocab at 0x7f624442f890>,
#  u'arrived': <gensim.models.keyedvectors.Vocab at 0x7f62443d5dd0>,
#  u'onto': <gensim.models.keyedvectors.Vocab at 0x7f624442f8d0>,
#  u'industrial': <gensim.models.keyedvectors.Vocab at 0x7f624440ef10>,
#  u'economists': <gensim.models.keyedvectors.Vocab at 0x7f62444721d0>,
#  u'grade': <gensim.models.keyedvectors.Vocab at 0x7f6244472210>,
#  u'chased': <gensim.models.keyedvectors.Vocab at 0x7f62444241d0>,
#  u'primary': <gensim.models.keyedvectors.Vocab at 0x7f624442f950>,
#  u'hearing': <gensim.models.keyedvectors.Vocab at 0x7f624442f990>,
#  u'fantasy': <gensim.models.keyedvectors.Vocab at 0x7f6244408e90>,
#  u'another': <gensim.models.keyedvectors.Vocab at 0x7f62444b0510>,
#  u'wasn': <gensim.models.keyedvectors.Vocab at 0x7f62444ee690>,
#  u'hear': <gensim.models.keyedvectors.Vocab at 0x7f624443ff90>,
#  u'thick': <gensim.models.keyedvectors.Vocab at 0x7f62444b0550>,
#  u'electronic': <gensim.models.keyedvectors.Vocab at 0x7f62444b0590>,
#  u'basketball': <gensim.models.keyedvectors.Vocab at 0x7f62444ee6d0>,
#  u'Ibid': <gensim.models.keyedvectors.Vocab at 0x7f6244495d50>,
#  u'similarly': <gensim.models.keyedvectors.Vocab at 0x7f62444ee750>,
#  u'top': <gensim.models.keyedvectors.Vocab at 0x7f624442fad0>,
#  u'engagement': <gensim.models.keyedvectors.Vocab at 0x7f62444ee790>,
#  u'girls': <gensim.models.keyedvectors.Vocab at 0x7f6244472250>,
#  u'needed': <gensim.models.keyedvectors.Vocab at 0x7f62444ee7d0>,
#  u'Uncle': <gensim.models.keyedvectors.Vocab at 0x7f62444b05d0>,
#  u'too': <gensim.models.keyedvectors.Vocab at 0x7f624442fb10>,
#  u'dogs': <gensim.models.keyedvectors.Vocab at 0x7f62444b0610>,
#  u'listen': <gensim.models.keyedvectors.Vocab at 0x7f62444ee810>,
#  u'urban': <gensim.models.keyedvectors.Vocab at 0x7f6244413750>,
#  u'murder': <gensim.models.keyedvectors.Vocab at 0x7f624442fb50>,
#  u'collapse': <gensim.models.keyedvectors.Vocab at 0x7f62444ee850>,
#  u'grandchildren': <gensim.models.keyedvectors.Vocab at 0x7f62444b0650>,
#  u'serve': <gensim.models.keyedvectors.Vocab at 0x7f6244413990>,
#  u'took': <gensim.models.keyedvectors.Vocab at 0x7f624442fb90>,
#  u'wisdom': <gensim.models.keyedvectors.Vocab at 0x7f62444ee890>,
#  u'predictable': <gensim.models.keyedvectors.Vocab at 0x7f62444ee8d0>,
#  u'somewhat': <gensim.models.keyedvectors.Vocab at 0x7f6244472290>,
#  u'practiced': <gensim.models.keyedvectors.Vocab at 0x7f6244478590>,
#  u'Daddy': <gensim.models.keyedvectors.Vocab at 0x7f62444ee910>,
#  u'positively': <gensim.models.keyedvectors.Vocab at 0x7f62444ee950>,
#  u'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f624445cf90>,
#  u'target': <gensim.models.keyedvectors.Vocab at 0x7f6244413e90>,
#  u'showed': <gensim.models.keyedvectors.Vocab at 0x7f62444ee990>,
#  u'Meibers': <gensim.models.keyedvectors.Vocab at 0x7f624442fbd0>,
#  u'immigrants': <gensim.models.keyedvectors.Vocab at 0x7f624442fc10>,
#  u'tree': <gensim.models.keyedvectors.Vocab at 0x7f62444ee9d0>,
#  u'likely': <gensim.models.keyedvectors.Vocab at 0x7f624446d090>,
#  u'project': <gensim.models.keyedvectors.Vocab at 0x7f62444eea10>,
#  u'matter': <gensim.models.keyedvectors.Vocab at 0x7f6244472350>,
#  u'classes': <gensim.models.keyedvectors.Vocab at 0x7f624442fc90>,
#  u'speaking': <gensim.models.keyedvectors.Vocab at 0x7f62444839d0>,
#  u'feeling': <gensim.models.keyedvectors.Vocab at 0x7f62444eea50>,
#  u'paths': <gensim.models.keyedvectors.Vocab at 0x7f62443d5d50>,
#  u'willingness': <gensim.models.keyedvectors.Vocab at 0x7f62444eea90>,
#  u'ran': <gensim.models.keyedvectors.Vocab at 0x7f624442fd10>,
#  u'modern': <gensim.models.keyedvectors.Vocab at 0x7f6244472390>,
#  u'mind': <gensim.models.keyedvectors.Vocab at 0x7f62444723d0>,
#  u'mine': <gensim.models.keyedvectors.Vocab at 0x7f6244472410>,
#  u'talking': <gensim.models.keyedvectors.Vocab at 0x7f6244419490>,
#  u'manner': <gensim.models.keyedvectors.Vocab at 0x7f62444b06d0>,
#  u'Instead': <gensim.models.keyedvectors.Vocab at 0x7f62444b0710>,
#  u'seem': <gensim.models.keyedvectors.Vocab at 0x7f6244472490>,
#  u'obviously': <gensim.models.keyedvectors.Vocab at 0x7f62444724d0>,
#  u'tells': <gensim.models.keyedvectors.Vocab at 0x7f6244472510>,
#  u'dozen': <gensim.models.keyedvectors.Vocab at 0x7f62444eead0>,
#  u'forced': <gensim.models.keyedvectors.Vocab at 0x7f62444b0750>,
#  u'strength': <gensim.models.keyedvectors.Vocab at 0x7f62444b0790>,
#  u'genuine': <gensim.models.keyedvectors.Vocab at 0x7f62444b07d0>,
#  u'latter': <gensim.models.keyedvectors.Vocab at 0x7f62444b0810>,
#  u'isolated': <gensim.models.keyedvectors.Vocab at 0x7f624442fdd0>,
#  u'investment': <gensim.models.keyedvectors.Vocab at 0x7f624442fe10>,
#  u'chest': <gensim.models.keyedvectors.Vocab at 0x7f6244472550>,
#  u'niece': <gensim.models.keyedvectors.Vocab at 0x7f6244495990>,
#  u'doors': <gensim.models.keyedvectors.Vocab at 0x7f62444eeb90>,
#  u'laughed': <gensim.models.keyedvectors.Vocab at 0x7f624442fe50>,
#  u'dragged': <gensim.models.keyedvectors.Vocab at 0x7f624448fd50>,
#  u'Jones': <gensim.models.keyedvectors.Vocab at 0x7f62444eebd0>,
#  u'blue': <gensim.models.keyedvectors.Vocab at 0x7f6244429bd0>,
#  u'though': <gensim.models.keyedvectors.Vocab at 0x7f624442fe90>,
#  u'metrics': <gensim.models.keyedvectors.Vocab at 0x7f62444eec10>,
#  u'audition': <gensim.models.keyedvectors.Vocab at 0x7f624442fed0>,
#  u'mouth': <gensim.models.keyedvectors.Vocab at 0x7f62444eec50>,
#  u'addict': <gensim.models.keyedvectors.Vocab at 0x7f62444eec90>,
#  u'letter': <gensim.models.keyedvectors.Vocab at 0x7f62444eecd0>,
#  u'Alabama': <gensim.models.keyedvectors.Vocab at 0x7f6244472590>,
#  u'episode': <gensim.models.keyedvectors.Vocab at 0x7f62444eed10>,
#  u'neighborhoods': <gensim.models.keyedvectors.Vocab at 0x7f62444b08d0>,
#  u'professor': <gensim.models.keyedvectors.Vocab at 0x7f62444eed50>,
#  u'camp': <gensim.models.keyedvectors.Vocab at 0x7f62444eed90>,
#  u'alumni': <gensim.models.keyedvectors.Vocab at 0x7f62444b0910>,
#  u'dog': <gensim.models.keyedvectors.Vocab at 0x7f6244472690>,
#  u'definitely': <gensim.models.keyedvectors.Vocab at 0x7f62444726d0>,
#  u'aunt': <gensim.models.keyedvectors.Vocab at 0x7f62444b0950>,
#  u'boyfriends': <gensim.models.keyedvectors.Vocab at 0x7f62444b09d0>,
#  u'scream': <gensim.models.keyedvectors.Vocab at 0x7f62444eedd0>,
#  u'came': <gensim.models.keyedvectors.Vocab at 0x7f624449a4d0>,
#  u'saying': <gensim.models.keyedvectors.Vocab at 0x7f62444eee10>,
#  u'bomb': <gensim.models.keyedvectors.Vocab at 0x7f62444eee50>,
#  u'officer': <gensim.models.keyedvectors.Vocab at 0x7f6244434f10>,
#  u'confront': <gensim.models.keyedvectors.Vocab at 0x7f62443db050>,
#  u'meetings': <gensim.models.keyedvectors.Vocab at 0x7f62444eee90>,
#  u'random': <gensim.models.keyedvectors.Vocab at 0x7f624441e290>,
#  u'prescription': <gensim.models.keyedvectors.Vocab at 0x7f62443d5710>,
#  u'radio': <gensim.models.keyedvectors.Vocab at 0x7f624442ffd0>,
#  u'nephew': <gensim.models.keyedvectors.Vocab at 0x7f62444b0a90>,
#  u'enjoyed': <gensim.models.keyedvectors.Vocab at 0x7f62444b0ad0>,
#  u'make': <gensim.models.keyedvectors.Vocab at 0x7f6244478410>,
#  u'lessons': <gensim.models.keyedvectors.Vocab at 0x7f62444eeed0>,
#  u'judges': <gensim.models.keyedvectors.Vocab at 0x7f6244472710>,
#  u'cousins': <gensim.models.keyedvectors.Vocab at 0x7f62444eef10>,
#  u'explain': <gensim.models.keyedvectors.Vocab at 0x7f6244472750>,
#  u'appreciated': <gensim.models.keyedvectors.Vocab at 0x7f62444c1550>,
#  u'about': <gensim.models.keyedvectors.Vocab at 0x7f62444293d0>,
#  u'rich': <gensim.models.keyedvectors.Vocab at 0x7f62444eef90>,
#  u'folks': <gensim.models.keyedvectors.Vocab at 0x7f6244472790>,
#  u'announce': <gensim.models.keyedvectors.Vocab at 0x7f62444340d0>,
#  u'population': <gensim.models.keyedvectors.Vocab at 0x7f624443fc50>,
#  u'wearing': <gensim.models.keyedvectors.Vocab at 0x7f62444727d0>,
#  u'plate': <gensim.models.keyedvectors.Vocab at 0x7f62444eefd0>,
#  u'Nevertheless': <gensim.models.keyedvectors.Vocab at 0x7f62444f4050>,
#  u'stop': <gensim.models.keyedvectors.Vocab at 0x7f6244472810>,
#  u'lenders': <gensim.models.keyedvectors.Vocab at 0x7f62444f4090>,
#  u'new': <gensim.models.keyedvectors.Vocab at 0x7f624446d150>,
#  u'report': <gensim.models.keyedvectors.Vocab at 0x7f6244434190>,
#  u'learned': <gensim.models.keyedvectors.Vocab at 0x7f624444c290>,
#  u'Armco': <gensim.models.keyedvectors.Vocab at 0x7f62444341d0>,
#  u'earn': <gensim.models.keyedvectors.Vocab at 0x7f6244472850>,
#  u'bar': <gensim.models.keyedvectors.Vocab at 0x7f6244472890>,
#  u'convinced': <gensim.models.keyedvectors.Vocab at 0x7f62443d0e90>,
#  u'Washington': <gensim.models.keyedvectors.Vocab at 0x7f62444728d0>,
#  u'bay': <gensim.models.keyedvectors.Vocab at 0x7f6244472910>,
#  u'bag': <gensim.models.keyedvectors.Vocab at 0x7f6244472950>,
#  u'bad': <gensim.models.keyedvectors.Vocab at 0x7f6244472990>,
#  u'eventually': <gensim.models.keyedvectors.Vocab at 0x7f62444086d0>,
#  u'ears': <gensim.models.keyedvectors.Vocab at 0x7f62444729d0>,
#  u'searching': <gensim.models.keyedvectors.Vocab at 0x7f62443e68d0>,
#  u'Jackson': <gensim.models.keyedvectors.Vocab at 0x7f62444b0b90>,
#  u'human': <gensim.models.keyedvectors.Vocab at 0x7f6244478790>,
#  u'observer': <gensim.models.keyedvectors.Vocab at 0x7f62444b0bd0>,
#  u'Pet': <gensim.models.keyedvectors.Vocab at 0x7f6244434250>,
#  u'Hospital': <gensim.models.keyedvectors.Vocab at 0x7f6244472a50>,
#  u'observed': <gensim.models.keyedvectors.Vocab at 0x7f62444b0c10>,
#  u'decided': <gensim.models.keyedvectors.Vocab at 0x7f6244472a90>,
#  u'result': <gensim.models.keyedvectors.Vocab at 0x7f62444f4110>,
#  u'fail': <gensim.models.keyedvectors.Vocab at 0x7f62444f4150>,
#  u'news': <gensim.models.keyedvectors.Vocab at 0x7f62444343d0>,
#  u'yes': <gensim.models.keyedvectors.Vocab at 0x7f62444787d0>,
#  u'best': <gensim.models.keyedvectors.Vocab at 0x7f62444f4190>,
#  u'subject': <gensim.models.keyedvectors.Vocab at 0x7f62444a0d10>,
#  u'said': <gensim.models.keyedvectors.Vocab at 0x7f6244472ad0>,
#  u'away': <gensim.models.keyedvectors.Vocab at 0x7f62444b0c50>,
#  u'grandmother': <gensim.models.keyedvectors.Vocab at 0x7f6244434310>,
#  u'pressures': <gensim.models.keyedvectors.Vocab at 0x7f62444f41d0>,
#  u'stamps': <gensim.models.keyedvectors.Vocab at 0x7f62444f4210>,
#  u'score': <gensim.models.keyedvectors.Vocab at 0x7f62444f4250>,
#  u'drawn': <gensim.models.keyedvectors.Vocab at 0x7f62444b0cd0>,
#  u'sorts': <gensim.models.keyedvectors.Vocab at 0x7f6244472b10>,
#  u'we': <gensim.models.keyedvectors.Vocab at 0x7f62444b0d10>,
#  u'men': <gensim.models.keyedvectors.Vocab at 0x7f624446d1d0>,
#  u'terms': <gensim.models.keyedvectors.Vocab at 0x7f62444b0d50>,
#  u'rolled': <gensim.models.keyedvectors.Vocab at 0x7f62444f42d0>,
#  u'ignorance': <gensim.models.keyedvectors.Vocab at 0x7f6244472b90>,
#  u'boss': <gensim.models.keyedvectors.Vocab at 0x7f6244434390>,
#  u'drew': <gensim.models.keyedvectors.Vocab at 0x7f624446d210>,
#  u'cousin': <gensim.models.keyedvectors.Vocab at 0x7f6244472bd0>,
#  u'debt': <gensim.models.keyedvectors.Vocab at 0x7f62444f4310>,
#  u'kitchen': <gensim.models.keyedvectors.Vocab at 0x7f62444b0d90>,
#  u'pity': <gensim.models.keyedvectors.Vocab at 0x7f62444f4350>,
#  u'received': <gensim.models.keyedvectors.Vocab at 0x7f62444b0dd0>,
#  u'protect': <gensim.models.keyedvectors.Vocab at 0x7f6244434490>,
#  u'met': <gensim.models.keyedvectors.Vocab at 0x7f624446d250>,
#  u'country': <gensim.models.keyedvectors.Vocab at 0x7f62444f4390>,
#  u'demanded': <gensim.models.keyedvectors.Vocab at 0x7f62444f43d0>,
#  u'games': <gensim.models.keyedvectors.Vocab at 0x7f6244434510>,
#  u'planned': <gensim.models.keyedvectors.Vocab at 0x7f62444f4410>,
#  u'marrying': <gensim.models.keyedvectors.Vocab at 0x7f62444198d0>,
#  u'com': <gensim.models.keyedvectors.Vocab at 0x7f62444b0e10>,
#  u'asked': <gensim.models.keyedvectors.Vocab at 0x7f62444f4490>,
#  u'tough': <gensim.models.keyedvectors.Vocab at 0x7f62444b0e50>,
#  u'appeared': <gensim.models.keyedvectors.Vocab at 0x7f6244472cd0>,
#  u'character': <gensim.models.keyedvectors.Vocab at 0x7f6244478850>,
#  u'Papaw': <gensim.models.keyedvectors.Vocab at 0x7f6244472d10>,
#  u'hardworking': <gensim.models.keyedvectors.Vocab at 0x7f6244472d50>,
#  u'height': <gensim.models.keyedvectors.Vocab at 0x7f6244472d90>,
#  u'active': <gensim.models.keyedvectors.Vocab at 0x7f624446d290>,
#  u'foray': <gensim.models.keyedvectors.Vocab at 0x7f6244472dd0>,
#  u'pregnancy': <gensim.models.keyedvectors.Vocab at 0x7f62444f44d0>,
#  u'loaded': <gensim.models.keyedvectors.Vocab at 0x7f6244472e10>,
#  u'trust': <gensim.models.keyedvectors.Vocab at 0x7f6244434590>,
#  u'speak': <gensim.models.keyedvectors.Vocab at 0x7f62444b0e90>,
#  u'conference': <gensim.models.keyedvectors.Vocab at 0x7f62444345d0>,
#  u'bathroom': <gensim.models.keyedvectors.Vocab at 0x7f6244434610>,
#  u'proceeded': <gensim.models.keyedvectors.Vocab at 0x7f6244472e50>,
#  u'Southern': <gensim.models.keyedvectors.Vocab at 0x7f6244434650>,
#  u'three': <gensim.models.keyedvectors.Vocab at 0x7f6244472e90>,
#  u'tiny': <gensim.models.keyedvectors.Vocab at 0x7f6244472ed0>,
#  u'quickly': <gensim.models.keyedvectors.Vocab at 0x7f62444346d0>,
#  u'beer': <gensim.models.keyedvectors.Vocab at 0x7f6244434710>,
#  u'much': <gensim.models.keyedvectors.Vocab at 0x7f62444f4510>,
#  u'interest': <gensim.models.keyedvectors.Vocab at 0x7f6244472f10>,
#  u'basic': <gensim.models.keyedvectors.Vocab at 0x7f6244472f50>,
#  u'privilege': <gensim.models.keyedvectors.Vocab at 0x7f62444f4550>,
#  u'dozens': <gensim.models.keyedvectors.Vocab at 0x7f62444b0ed0>,
#  u'threw': <gensim.models.keyedvectors.Vocab at 0x7f6244472f90>,
#  u'life': <gensim.models.keyedvectors.Vocab at 0x7f62444f4590>,
#  u'families': <gensim.models.keyedvectors.Vocab at 0x7f62444b0f10>,
#  u'easy': <gensim.models.keyedvectors.Vocab at 0x7f62444f4ad0>,
#  u'spit': <gensim.models.keyedvectors.Vocab at 0x7f62444f4610>,
#  u'eastern': <gensim.models.keyedvectors.Vocab at 0x7f62444f4650>,
#  u'drugs': <gensim.models.keyedvectors.Vocab at 0x7f6244434790>,
#  u'uncommon': <gensim.models.keyedvectors.Vocab at 0x7f62444347d0>,
#  u'marijuana': <gensim.models.keyedvectors.Vocab at 0x7f6244483b10>,
#  u'Rachael': <gensim.models.keyedvectors.Vocab at 0x7f62444ab590>,
#  u'child': <gensim.models.keyedvectors.Vocab at 0x7f62444f4690>,
#  u'catch': <gensim.models.keyedvectors.Vocab at 0x7f6244434810>,
#  u'worked': <gensim.models.keyedvectors.Vocab at 0x7f62444f46d0>,
#  u'voices': <gensim.models.keyedvectors.Vocab at 0x7f6244483b50>,
#  u'applied': <gensim.models.keyedvectors.Vocab at 0x7f62444b0f90>,
#  u'exception': <gensim.models.keyedvectors.Vocab at 0x7f62444780d0>,
#  u'save': <gensim.models.keyedvectors.Vocab at 0x7f62444788d0>,
#  u'economies': <gensim.models.keyedvectors.Vocab at 0x7f6244478110>,
#  u'air': <gensim.models.keyedvectors.Vocab at 0x7f62444b0fd0>,
#  u'near': <gensim.models.keyedvectors.Vocab at 0x7f6244478150>,
#  u'suppose': <gensim.models.keyedvectors.Vocab at 0x7f6244478190>,
#  u'HarperCollins': <gensim.models.keyedvectors.Vocab at 0x7f624445c910>,
#  u'aid': <gensim.models.keyedvectors.Vocab at 0x7f62444b6050>,
#  u'cracked': <gensim.models.keyedvectors.Vocab at 0x7f62444348d0>,
#  u'property': <gensim.models.keyedvectors.Vocab at 0x7f62444b6090>,
#  u'Tuesday': <gensim.models.keyedvectors.Vocab at 0x7f624457b890>,
#  u'mistake': <gensim.models.keyedvectors.Vocab at 0x7f62444b60d0>,
#  u'remembering': <gensim.models.keyedvectors.Vocab at 0x7f62444f4710>,
#  u'seven': <gensim.models.keyedvectors.Vocab at 0x7f6244478250>,
#  u'played': <gensim.models.keyedvectors.Vocab at 0x7f62444f4750>,
#  u'is': <gensim.models.keyedvectors.Vocab at 0x7f6244478290>,
#  u'it': <gensim.models.keyedvectors.Vocab at 0x7f62444782d0>,
#  u'Bush': <gensim.models.keyedvectors.Vocab at 0x7f6244434910>,
#  u'eighteen': <gensim.models.keyedvectors.Vocab at 0x7f62444f4790>,
#  u'in': <gensim.models.keyedvectors.Vocab at 0x7f6244478310>,
#  u'disappear': <gensim.models.keyedvectors.Vocab at 0x7f6244478350>,
#  u'if': <gensim.models.keyedvectors.Vocab at 0x7f6244478390>,
#  u'grown': <gensim.models.keyedvectors.Vocab at 0x7f62444783d0>,
#  u'confirmed': <gensim.models.keyedvectors.Vocab at 0x7f62444b6110>,
#  u'things': <gensim.models.keyedvectors.Vocab at 0x7f62444f4810>,
#  u'realizing': <gensim.models.keyedvectors.Vocab at 0x7f62444f98d0>,
#  u'Oh': <gensim.models.keyedvectors.Vocab at 0x7f62444f4850>,
#  u'forehead': <gensim.models.keyedvectors.Vocab at 0x7f624442f450>,
#  u'complex': <gensim.models.keyedvectors.Vocab at 0x7f62444349d0>,
#  u'split': <gensim.models.keyedvectors.Vocab at 0x7f62444f4890>,
#  u'babies': <gensim.models.keyedvectors.Vocab at 0x7f62444f48d0>,
#  u'big': <gensim.models.keyedvectors.Vocab at 0x7f62444199d0>,
#  u'plates': <gensim.models.keyedvectors.Vocab at 0x7f62444b6150>,
#  u'several': <gensim.models.keyedvectors.Vocab at 0x7f6244434a10>,
#  u'Do': <gensim.models.keyedvectors.Vocab at 0x7f6244483bd0>,
#  u'Institute': <gensim.models.keyedvectors.Vocab at 0x7f62444b6190>,
#  u'Maybe': <gensim.models.keyedvectors.Vocab at 0x7f62444f4910>,
#  u'misery': <gensim.models.keyedvectors.Vocab at 0x7f624440e7d0>,
#  u'evil': <gensim.models.keyedvectors.Vocab at 0x7f62444b61d0>,
#  u'hand': <gensim.models.keyedvectors.Vocab at 0x7f62444b6210>,
#  u'marched': <gensim.models.keyedvectors.Vocab at 0x7f62444f4950>,
#  u'kin': <gensim.models.keyedvectors.Vocab at 0x7f6244478450>,
#  u'protected': <gensim.models.keyedvectors.Vocab at 0x7f6244483a90>,
#  u'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f6244478490>,
#  u'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f62444784d0>,
#  u'kid': <gensim.models.keyedvectors.Vocab at 0x7f6244478510>,
#  u'butter': <gensim.models.keyedvectors.Vocab at 0x7f6244478550>,
#  u'kept': <gensim.models.keyedvectors.Vocab at 0x7f62444b6250>,
#  u'kicked': <gensim.models.keyedvectors.Vocab at 0x7f6244429c90>,
#  u'possessed': <gensim.models.keyedvectors.Vocab at 0x7f6244434b10>,
#  u'failing': <gensim.models.keyedvectors.Vocab at 0x7f62444785d0>,
#  u'mentors': <gensim.models.keyedvectors.Vocab at 0x7f62444f4990>,
#  u'T': <gensim.models.keyedvectors.Vocab at 0x7f62443e6790>,
#  u'academic': <gensim.models.keyedvectors.Vocab at 0x7f62444f49d0>,
#  u'contact': <gensim.models.keyedvectors.Vocab at 0x7f62444b62d0>,
#  u'greatest': <gensim.models.keyedvectors.Vocab at 0x7f6244434b50>,
#  u'mother': <gensim.models.keyedvectors.Vocab at 0x7f6244434b90>,
#  u'hearts': <gensim.models.keyedvectors.Vocab at 0x7f624442ff50>,
#  u'the': <gensim.models.keyedvectors.Vocab at 0x7f62444b6310>,
#  u'yours': <gensim.models.keyedvectors.Vocab at 0x7f6244478610>,
#  u'left': <gensim.models.keyedvectors.Vocab at 0x7f6244478650>,
#  u'grandkids': <gensim.models.keyedvectors.Vocab at 0x7f624446d390>,
#  u'background': <gensim.models.keyedvectors.Vocab at 0x7f6244478950>,
#  u'just': <gensim.models.keyedvectors.Vocab at 0x7f6244478690>,
#  u'sentence': <gensim.models.keyedvectors.Vocab at 0x7f62444786d0>,
#  u'hillbilly': <gensim.models.keyedvectors.Vocab at 0x7f6244478710>,
#  u'assigned': <gensim.models.keyedvectors.Vocab at 0x7f6244478750>,
#  u'grades': <gensim.models.keyedvectors.Vocab at 0x7f6244434c10>,
#  u'thanks': <gensim.models.keyedvectors.Vocab at 0x7f62444b6350>,
#  u'victim': <gensim.models.keyedvectors.Vocab at 0x7f62444b6390>,
#  u'plight': <gensim.models.keyedvectors.Vocab at 0x7f62444f4a10>,
#  u'yet': <gensim.models.keyedvectors.Vocab at 0x7f6244478810>,
#  u'previous': <gensim.models.keyedvectors.Vocab at 0x7f62444f4a50>,
#  u'Protestants': <gensim.models.keyedvectors.Vocab at 0x7f6244434c50>,
#  u'hills': <gensim.models.keyedvectors.Vocab at 0x7f62444b63d0>,
#  u'Everything': <gensim.models.keyedvectors.Vocab at 0x7f62443db250>,
#  u'had': <gensim.models.keyedvectors.Vocab at 0x7f62444f4a90>,
#  u'pharmacy': <gensim.models.keyedvectors.Vocab at 0x7f6244434c90>,
#  u'spread': <gensim.models.keyedvectors.Vocab at 0x7f62444b6410>,
#  u'board': <gensim.models.keyedvectors.Vocab at 0x7f62444b6450>,
#  u'beloved': <gensim.models.keyedvectors.Vocab at 0x7f62444b0f50>,
#  u'prison': <gensim.models.keyedvectors.Vocab at 0x7f62444f4b10>,
#  u'News': <gensim.models.keyedvectors.Vocab at 0x7f6244478890>,
#  u'has': <gensim.models.keyedvectors.Vocab at 0x7f62444f4b50>,
#  u'gave': <gensim.models.keyedvectors.Vocab at 0x7f6244434d10>,
#  u'D': <gensim.models.keyedvectors.Vocab at 0x7f6244434d50>,
#  u'Bowman': <gensim.models.keyedvectors.Vocab at 0x7f6244478910>,
#  u'James': <gensim.models.keyedvectors.Vocab at 0x7f6244434d90>,
#  u'possible': <gensim.models.keyedvectors.Vocab at 0x7f62444f4b90>,
#  u'possibly': <gensim.models.keyedvectors.Vocab at 0x7f62444f4bd0>,
#  u'cultural': <gensim.models.keyedvectors.Vocab at 0x7f6244434e10>,
#  u'birth': <gensim.models.keyedvectors.Vocab at 0x7f62444f4c10>,
#  u'judge': <gensim.models.keyedvectors.Vocab at 0x7f6244434e50>,
#  u'unique': <gensim.models.keyedvectors.Vocab at 0x7f62444f4c50>,
#  u'dreams': <gensim.models.keyedvectors.Vocab at 0x7f6244478990>,
#  u'apart': <gensim.models.keyedvectors.Vocab at 0x7f6244434ed0>,
#  u'desire': <gensim.models.keyedvectors.Vocab at 0x7f62444f4c90>,
#  u'county': <gensim.models.keyedvectors.Vocab at 0x7f624446d490>,
#  u'unnecessary': <gensim.models.keyedvectors.Vocab at 0x7f62444789d0>,
#  u'steps': <gensim.models.keyedvectors.Vocab at 0x7f62444f4d10>,
#  u'Migration': <gensim.models.keyedvectors.Vocab at 0x7f62444f4d50>,
#  u'night': <gensim.models.keyedvectors.Vocab at 0x7f62444b6490>,
#  u'hung': <gensim.models.keyedvectors.Vocab at 0x7f6244434f50>,
#  u'security': <gensim.models.keyedvectors.Vocab at 0x7f62444b64d0>,
#  u'attorney': <gensim.models.keyedvectors.Vocab at 0x7f62444f4d90>,
#  u'right': <gensim.models.keyedvectors.Vocab at 0x7f62444f4dd0>,
#  u'old': <gensim.models.keyedvectors.Vocab at 0x7f62444f4e10>,
#  u'crowd': <gensim.models.keyedvectors.Vocab at 0x7f62444f4e50>,
#  u'people': <gensim.models.keyedvectors.Vocab at 0x7f62444f4e90>,
#  u'understand': <gensim.models.keyedvectors.Vocab at 0x7f6244419450>,
#  u'proudly': <gensim.models.keyedvectors.Vocab at 0x7f6244434fd0>,
#  u'somehow': <gensim.models.keyedvectors.Vocab at 0x7f6244478b50>,
#  u'dead': <gensim.models.keyedvectors.Vocab at 0x7f6244478b90>,
#  u'born': <gensim.models.keyedvectors.Vocab at 0x7f62443d5fd0>,
#  u'Tina': <gensim.models.keyedvectors.Vocab at 0x7f62444b6510>,
#  u'escape': <gensim.models.keyedvectors.Vocab at 0x7f624443a050>,
#  u'multiple': <gensim.models.keyedvectors.Vocab at 0x7f624443fe10>,
#  u'embodied': <gensim.models.keyedvectors.Vocab at 0x7f624443a090>,
#  u'Breathitt': <gensim.models.keyedvectors.Vocab at 0x7f6244478bd0>,
#  u'humor': <gensim.models.keyedvectors.Vocab at 0x7f62444b6550>,
#  u'Lee': <gensim.models.keyedvectors.Vocab at 0x7f62444b6590>,
#  u'for': <gensim.models.keyedvectors.Vocab at 0x7f62444f4f10>,
#  u'bottom': <gensim.models.keyedvectors.Vocab at 0x7f62444f4f50>,
#  u'ice': <gensim.models.keyedvectors.Vocab at 0x7f624443a0d0>,
#  u'arguing': <gensim.models.keyedvectors.Vocab at 0x7f6244483d50>,
#  u'asking': <gensim.models.keyedvectors.Vocab at 0x7f62444b65d0>,
#  u'Facebook': <gensim.models.keyedvectors.Vocab at 0x7f62444f4f90>,
#  u'Chris': <gensim.models.keyedvectors.Vocab at 0x7f624443a150>,
#  u'Marines': <gensim.models.keyedvectors.Vocab at 0x7f6244478090>,
#  u'heartbroken': <gensim.models.keyedvectors.Vocab at 0x7f624444c4d0>,
#  u'Are': <gensim.models.keyedvectors.Vocab at 0x7f6244478a10>,
#  u'core': <gensim.models.keyedvectors.Vocab at 0x7f624443a1d0>,
#  u'School': <gensim.models.keyedvectors.Vocab at 0x7f62444b6610>,
#  u'dental': <gensim.models.keyedvectors.Vocab at 0x7f62444f4fd0>,
#  u'decisions': <gensim.models.keyedvectors.Vocab at 0x7f62443caa50>,
#  u'graduates': <gensim.models.keyedvectors.Vocab at 0x7f62444b6650>,
#  u'staunchly': <gensim.models.keyedvectors.Vocab at 0x7f624443a210>,
#  u'paid': <gensim.models.keyedvectors.Vocab at 0x7f6244483d90>,
#  u'graduated': <gensim.models.keyedvectors.Vocab at 0x7f62444b6690>,
#  u'eye': <gensim.models.keyedvectors.Vocab at 0x7f624440e850>,
#  u'post': <gensim.models.keyedvectors.Vocab at 0x7f62444b66d0>,
#  u'manufacturing': <gensim.models.keyedvectors.Vocab at 0x7f62444f9090>,
#  u'First': <gensim.models.keyedvectors.Vocab at 0x7f62444f90d0>,
#  u'increasingly': <gensim.models.keyedvectors.Vocab at 0x7f6244462f50>,
#  u'dollars': <gensim.models.keyedvectors.Vocab at 0x7f62444f9110>,
#  u'months': <gensim.models.keyedvectors.Vocab at 0x7f62444b6710>,
#  u'trustworthy': <gensim.models.keyedvectors.Vocab at 0x7f624443a250>,
#  u'dinner': <gensim.models.keyedvectors.Vocab at 0x7f624443a290>,
#  u'ensure': <gensim.models.keyedvectors.Vocab at 0x7f624443a2d0>,
#  u'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f6244478c90>,
#  u'commit': <gensim.models.keyedvectors.Vocab at 0x7f6244478cd0>,
#  u'lacked': <gensim.models.keyedvectors.Vocab at 0x7f62444f9150>,
#  u'Still': <gensim.models.keyedvectors.Vocab at 0x7f624443a350>,
#  u'raised': <gensim.models.keyedvectors.Vocab at 0x7f62444f9190>,
#  u'lied': <gensim.models.keyedvectors.Vocab at 0x7f6244478d10>,
#  u'presence': <gensim.models.keyedvectors.Vocab at 0x7f624443a390>,
#  u'civil': <gensim.models.keyedvectors.Vocab at 0x7f624443a3d0>,
#  u'material': <gensim.models.keyedvectors.Vocab at 0x7f62443e0390>,
#  u'profession': <gensim.models.keyedvectors.Vocab at 0x7f62444b6750>,
#  u'www': <gensim.models.keyedvectors.Vocab at 0x7f6244478a50>,
#  u'son': <gensim.models.keyedvectors.Vocab at 0x7f62444f91d0>,
#  u'down': <gensim.models.keyedvectors.Vocab at 0x7f6244478d50>,
#  u'respectable': <gensim.models.keyedvectors.Vocab at 0x7f62444bbb50>,
#  u'dean': <gensim.models.keyedvectors.Vocab at 0x7f6244478a90>,
#  u'frightened': <gensim.models.keyedvectors.Vocab at 0x7f6244478dd0>,
#  u'existed': <gensim.models.keyedvectors.Vocab at 0x7f624443a410>,
#  u'rely': <gensim.models.keyedvectors.Vocab at 0x7f624443a450>,
#  u'deal': <gensim.models.keyedvectors.Vocab at 0x7f6244478ad0>,
#  u'support': <gensim.models.keyedvectors.Vocab at 0x7f62444f9210>,
#  u'flying': <gensim.models.keyedvectors.Vocab at 0x7f62444c1150>,
#  u'fight': <gensim.models.keyedvectors.Vocab at 0x7f62444b6790>,
#  u'fucking': <gensim.models.keyedvectors.Vocab at 0x7f62443db0d0>,
#  u'quirks': <gensim.models.keyedvectors.Vocab at 0x7f62444b67d0>,
#  u'editor': <gensim.models.keyedvectors.Vocab at 0x7f6244478e10>,
#  u'way': <gensim.models.keyedvectors.Vocab at 0x7f62444b6810>,
#  u'obliged': <gensim.models.keyedvectors.Vocab at 0x7f6244419b50>,
#  u'call': <gensim.models.keyedvectors.Vocab at 0x7f624446d550>,
#  u'was': <gensim.models.keyedvectors.Vocab at 0x7f62444b6850>,
#  u'war': <gensim.models.keyedvectors.Vocab at 0x7f62444b6890>,
#  u'happy': <gensim.models.keyedvectors.Vocab at 0x7f62444f9290>,
#  u'head': <gensim.models.keyedvectors.Vocab at 0x7f624443a510>,
#  u'medium': <gensim.models.keyedvectors.Vocab at 0x7f624443a550>,
#  u'form': <gensim.models.keyedvectors.Vocab at 0x7f62444c16d0>,
#  u'offer': <gensim.models.keyedvectors.Vocab at 0x7f62444f92d0>,
#  u'January': <gensim.models.keyedvectors.Vocab at 0x7f6244478e90>,
#  u'becoming': <gensim.models.keyedvectors.Vocab at 0x7f62444b68d0>,
#  u'failure': <gensim.models.keyedvectors.Vocab at 0x7f6244478ed0>,
#  u'uncle': <gensim.models.keyedvectors.Vocab at 0x7f624443a610>,
#  u'true': <gensim.models.keyedvectors.Vocab at 0x7f62444b6910>,
#  u'traits': <gensim.models.keyedvectors.Vocab at 0x7f62443db110>,
#  u'inside': <gensim.models.keyedvectors.Vocab at 0x7f62444f9310>,
#  u'morning': <gensim.models.keyedvectors.Vocab at 0x7f6244483510>,
#  u'attached': <gensim.models.keyedvectors.Vocab at 0x7f6244478f50>,
#  u'tell': <gensim.models.keyedvectors.Vocab at 0x7f624446d650>,
#  u'County': <gensim.models.keyedvectors.Vocab at 0x7f62444f9350>,
#  u'generosity': <gensim.models.keyedvectors.Vocab at 0x7f62444b6950>,
#  u'nicest': <gensim.models.keyedvectors.Vocab at 0x7f62444f9390>,
#  u'Tony': <gensim.models.keyedvectors.Vocab at 0x7f62444c1d50>,
#  u'emotional': <gensim.models.keyedvectors.Vocab at 0x7f62444b6990>,
#  u'temper': <gensim.models.keyedvectors.Vocab at 0x7f6244478f90>,
#  u'breathe': <gensim.models.keyedvectors.Vocab at 0x7f6244429ed0>,
#  u'later': <gensim.models.keyedvectors.Vocab at 0x7f624443ff10>,
#  u'liberal': <gensim.models.keyedvectors.Vocab at 0x7f62444f9410>,
#  u'classic': <gensim.models.keyedvectors.Vocab at 0x7f6244478fd0>,
#  u'upset': <gensim.models.keyedvectors.Vocab at 0x7f6244462350>,
#  u'hungry': <gensim.models.keyedvectors.Vocab at 0x7f624443ff50>,
#  u'exist': <gensim.models.keyedvectors.Vocab at 0x7f62444f9490>,
#  u'promised': <gensim.models.keyedvectors.Vocab at 0x7f62444b6a10>,
#  u'mediocre': <gensim.models.keyedvectors.Vocab at 0x7f62444a0290>,
#  u'trip': <gensim.models.keyedvectors.Vocab at 0x7f624443a690>,
#  u'shit': <gensim.models.keyedvectors.Vocab at 0x7f6244446250>,
#  u'physical': <gensim.models.keyedvectors.Vocab at 0x7f62443c5bd0>,
#  u'High': <gensim.models.keyedvectors.Vocab at 0x7f62443e0a90>,
#  u'protested': <gensim.models.keyedvectors.Vocab at 0x7f62444462d0>,
#  u'faithful': <gensim.models.keyedvectors.Vocab at 0x7f624443a710>,
#  u'aunts': <gensim.models.keyedvectors.Vocab at 0x7f624447d050>,
#  u'floor': <gensim.models.keyedvectors.Vocab at 0x7f62444f9510>,
#  u'generally': <gensim.models.keyedvectors.Vocab at 0x7f6244446390>,
#  u'courthouse': <gensim.models.keyedvectors.Vocab at 0x7f624443f590>,
#  u'handed': <gensim.models.keyedvectors.Vocab at 0x7f624447d090>,
#  u'reality': <gensim.models.keyedvectors.Vocab at 0x7f62444b6a50>,
#  u'flood': <gensim.models.keyedvectors.Vocab at 0x7f62444f9550>,
#  u'interested': <gensim.models.keyedvectors.Vocab at 0x7f62444b6a90>,
#  u'role': <gensim.models.keyedvectors.Vocab at 0x7f62444f9590>,
#  u'holding': <gensim.models.keyedvectors.Vocab at 0x7f62444b6ad0>,
#  u'papers': <gensim.models.keyedvectors.Vocab at 0x7f624443a7d0>,
#  u'test': <gensim.models.keyedvectors.Vocab at 0x7f62444b6b10>,
#  u'vanished': <gensim.models.keyedvectors.Vocab at 0x7f624443a810>,
#  u'scored': <gensim.models.keyedvectors.Vocab at 0x7f62444b6b50>,
#  u'E': <gensim.models.keyedvectors.Vocab at 0x7f62444f95d0>,
#  u'brothers': <gensim.models.keyedvectors.Vocab at 0x7f62444b6b90>,
#  u'models': <gensim.models.keyedvectors.Vocab at 0x7f62444f9610>,
#  u'why': <gensim.models.keyedvectors.Vocab at 0x7f62443e0a10>,
#  u'felt': <gensim.models.keyedvectors.Vocab at 0x7f62444467d0>,
#  u'stealing': <gensim.models.keyedvectors.Vocab at 0x7f624446df50>,
#  u'fell': <gensim.models.keyedvectors.Vocab at 0x7f624447d110>,
#  u'occasion': <gensim.models.keyedvectors.Vocab at 0x7f6244424550>,
#  u'aware': <gensim.models.keyedvectors.Vocab at 0x7f62444abb90>,
#  u'weekend': <gensim.models.keyedvectors.Vocab at 0x7f624447d150>,
#  u'died': <gensim.models.keyedvectors.Vocab at 0x7f624447d190>,
#  u'grief': <gensim.models.keyedvectors.Vocab at 0x7f6244429f10>,
#  u'younger': <gensim.models.keyedvectors.Vocab at 0x7f624443a890>,
#  u'happening': <gensim.models.keyedvectors.Vocab at 0x7f624447d1d0>,
#  u'apology': <gensim.models.keyedvectors.Vocab at 0x7f624447d210>,
#  u'Taulbee': <gensim.models.keyedvectors.Vocab at 0x7f624440e8d0>,
# ...
#  u'terror': <gensim.models.keyedvectors.Vocab at 0x7f62444b6dd0>,
#  u'suffered': <gensim.models.keyedvectors.Vocab at 0x7f624447d510>,
#  u'must': <gensim.models.keyedvectors.Vocab at 0x7f6244429fd0>,
#  u'southwest': <gensim.models.keyedvectors.Vocab at 0x7f62444b6e10>,
#  u'shoot': <gensim.models.keyedvectors.Vocab at 0x7f624442f050>,
#  u'FIP': <gensim.models.keyedvectors.Vocab at 0x7f624447d590>,
#  u'advantage': <gensim.models.keyedvectors.Vocab at 0x7f624443ac10>,
#  u'seemingly': <gensim.models.keyedvectors.Vocab at 0x7f62444b6e50>,
#  u'choice': <gensim.models.keyedvectors.Vocab at 0x7f62444f9750>,
#  u'advised': <gensim.models.keyedvectors.Vocab at 0x7f624447d5d0>,
#  u'join': <gensim.models.keyedvectors.Vocab at 0x7f624442f090>,
#  u'trouble': <gensim.models.keyedvectors.Vocab at 0x7f62444b6e90>,
#  u'Where': <gensim.models.keyedvectors.Vocab at 0x7f624447d610>,
#  u'minute': <gensim.models.keyedvectors.Vocab at 0x7f62444f9790>,
#  u'room': <gensim.models.keyedvectors.Vocab at 0x7f624446d710>,
#  u'perceived': <gensim.models.keyedvectors.Vocab at 0x7f62444b6ed0>,
#  u'Just': <gensim.models.keyedvectors.Vocab at 0x7f62444b6f10>,
#  u'Religion': <gensim.models.keyedvectors.Vocab at 0x7f6244424650>,
#  u'did': <gensim.models.keyedvectors.Vocab at 0x7f624447d650>,
#  u'die': <gensim.models.keyedvectors.Vocab at 0x7f624447d690>,
#  u'gun': <gensim.models.keyedvectors.Vocab at 0x7f62444b6f50>,
#  u'standards': <gensim.models.keyedvectors.Vocab at 0x7f624443ad50>,
#  u'leave': <gensim.models.keyedvectors.Vocab at 0x7f62444f97d0>,
#  u'team': <gensim.models.keyedvectors.Vocab at 0x7f62444f9810>,
#  u'guy': <gensim.models.keyedvectors.Vocab at 0x7f62444b6f90>,
#  u'teenager': <gensim.models.keyedvectors.Vocab at 0x7f6244434cd0>,
#  u'George': <gensim.models.keyedvectors.Vocab at 0x7f62444b6fd0>,
#  u'Kevin': <gensim.models.keyedvectors.Vocab at 0x7f62443e0690>,
#  u'upper': <gensim.models.keyedvectors.Vocab at 0x7f62444bb050>,
#  u'spiritual': <gensim.models.keyedvectors.Vocab at 0x7f62444f9850>,
#  u'talked': <gensim.models.keyedvectors.Vocab at 0x7f624447d710>,
#  u'says': <gensim.models.keyedvectors.Vocab at 0x7f624443add0>,
#  u'regret': <gensim.models.keyedvectors.Vocab at 0x7f62444bb090>,
#  u'sign': <gensim.models.keyedvectors.Vocab at 0x7f6244451390>,
#  u'cost': <gensim.models.keyedvectors.Vocab at 0x7f62444bb0d0>,
#  u'Rick': <gensim.models.keyedvectors.Vocab at 0x7f62444bb110>,
#  u'Jane': <gensim.models.keyedvectors.Vocab at 0x7f624443ae10>,
#  u'run': <gensim.models.keyedvectors.Vocab at 0x7f624447d750>,
#  u'fear': <gensim.models.keyedvectors.Vocab at 0x7f62443e0b10>,
#  u'Red': <gensim.models.keyedvectors.Vocab at 0x7f624443ae90>,
#  u'stressful': <gensim.models.keyedvectors.Vocab at 0x7f624443aed0>,
#  u'assistance': <gensim.models.keyedvectors.Vocab at 0x7f62443d5250>,
#  u'celebrated': <gensim.models.keyedvectors.Vocab at 0x7f62444f9890>,
#  u'remain': <gensim.models.keyedvectors.Vocab at 0x7f624440ead0>,
#  u'Ford': <gensim.models.keyedvectors.Vocab at 0x7f62444bb150>,
#  u'health': <gensim.models.keyedvectors.Vocab at 0x7f62443d0910>,
#  u'suspect': <gensim.models.keyedvectors.Vocab at 0x7f624447d790>,
#  u'goes': <gensim.models.keyedvectors.Vocab at 0x7f624443af10>,
#  u'shared': <gensim.models.keyedvectors.Vocab at 0x7f62444bb190>,
#  u'geography': <gensim.models.keyedvectors.Vocab at 0x7f62444f9910>,
#  u'filled': <gensim.models.keyedvectors.Vocab at 0x7f624447d7d0>,
#  u'unsure': <gensim.models.keyedvectors.Vocab at 0x7f62444bb1d0>,
#  u'submitted': <gensim.models.keyedvectors.Vocab at 0x7f62444342d0>,
#  u'grandparents': <gensim.models.keyedvectors.Vocab at 0x7f62444f9950>,
#  u'funeral': <gensim.models.keyedvectors.Vocab at 0x7f62444f9990>,
#  u'perverts': <gensim.models.keyedvectors.Vocab at 0x7f62443d0310>,
#  u'understanding': <gensim.models.keyedvectors.Vocab at 0x7f62444f99d0>,
#  u'water': <gensim.models.keyedvectors.Vocab at 0x7f624443af90>,
#  u'yards': <gensim.models.keyedvectors.Vocab at 0x7f6244451cd0>,
#  u'address': <gensim.models.keyedvectors.Vocab at 0x7f62444f9a10>,
#  u'alone': <gensim.models.keyedvectors.Vocab at 0x7f62444f9a50>,
#  u'grabbed': <gensim.models.keyedvectors.Vocab at 0x7f62444246d0>,
#  u'along': <gensim.models.keyedvectors.Vocab at 0x7f62444f9a90>,
#  u'David': <gensim.models.keyedvectors.Vocab at 0x7f6244419d90>,
#  u'My': <gensim.models.keyedvectors.Vocab at 0x7f62444f9ad0>,
#  u'teacher': <gensim.models.keyedvectors.Vocab at 0x7f62444bb210>,
#  u'change': <gensim.models.keyedvectors.Vocab at 0x7f62444bb250>,
#  u'wait': <gensim.models.keyedvectors.Vocab at 0x7f624447d890>,
#  u'box': <gensim.models.keyedvectors.Vocab at 0x7f624447d8d0>,
#  u'boy': <gensim.models.keyedvectors.Vocab at 0x7f624447d910>,
#  u'thirty': <gensim.models.keyedvectors.Vocab at 0x7f624443f050>,
#  u'lazy': <gensim.models.keyedvectors.Vocab at 0x7f6244472b50>,
#  u'studied': <gensim.models.keyedvectors.Vocab at 0x7f62444f9b10>,
#  u'wherever': <gensim.models.keyedvectors.Vocab at 0x7f62444f9b50>,
#  u'trial': <gensim.models.keyedvectors.Vocab at 0x7f62444bb290>,
#  u'accomplished': <gensim.models.keyedvectors.Vocab at 0x7f62444f9b90>,
#  u'suggestion': <gensim.models.keyedvectors.Vocab at 0x7f624447d950>,
#  u'usually': <gensim.models.keyedvectors.Vocab at 0x7f62444bb2d0>,
#  u'weird': <gensim.models.keyedvectors.Vocab at 0x7f624443f150>,
#  u'studies': <gensim.models.keyedvectors.Vocab at 0x7f62444f9bd0>,
#  u'genuinely': <gensim.models.keyedvectors.Vocab at 0x7f624447d990>,
#  u'teenage': <gensim.models.keyedvectors.Vocab at 0x7f624447d9d0>,
#  u'love': <gensim.models.keyedvectors.Vocab at 0x7f62444f9c10>,
#  u'extra': <gensim.models.keyedvectors.Vocab at 0x7f62444bb310>,
#  u'When': <gensim.models.keyedvectors.Vocab at 0x7f624447da50>,
#  u'losing': <gensim.models.keyedvectors.Vocab at 0x7f62444f9050>,
#  u'rarely': <gensim.models.keyedvectors.Vocab at 0x7f62444bb350>,
#  u'crisis': <gensim.models.keyedvectors.Vocab at 0x7f624443f190>,
#  u'Australia': <gensim.models.keyedvectors.Vocab at 0x7f624447da90>,
#  u'August': <gensim.models.keyedvectors.Vocab at 0x7f62444f9cd0>,
#  u'working': <gensim.models.keyedvectors.Vocab at 0x7f62444f9d10>,
#  u'prove': <gensim.models.keyedvectors.Vocab at 0x7f62444bb390>,
#  u'sake': <gensim.models.keyedvectors.Vocab at 0x7f624447dad0>,
#  u'positive': <gensim.models.keyedvectors.Vocab at 0x7f62444f9d50>,
#  u'angry': <gensim.models.keyedvectors.Vocab at 0x7f62444f9d90>,
#  u'Deaton': <gensim.models.keyedvectors.Vocab at 0x7f62444f9dd0>,
#  u'visit': <gensim.models.keyedvectors.Vocab at 0x7f624447db10>,
#  u'only': <gensim.models.keyedvectors.Vocab at 0x7f62444c19d0>,
#  u'intense': <gensim.models.keyedvectors.Vocab at 0x7f62443db190>,
#  u'live': <gensim.models.keyedvectors.Vocab at 0x7f62444bb410>,
#  u'wondering': <gensim.models.keyedvectors.Vocab at 0x7f62444f9e10>,
#  u'memory': <gensim.models.keyedvectors.Vocab at 0x7f624443f1d0>,
#  u'scope': <gensim.models.keyedvectors.Vocab at 0x7f62444f9e50>,
#  u'Those': <gensim.models.keyedvectors.Vocab at 0x7f62444f9e90>,
#  u'loving': <gensim.models.keyedvectors.Vocab at 0x7f62444f9ed0>,
#  u'afford': <gensim.models.keyedvectors.Vocab at 0x7f62444f9f10>,
#  u'share': <gensim.models.keyedvectors.Vocab at 0x7f624440eb50>,
#  u'acceptable': <gensim.models.keyedvectors.Vocab at 0x7f624447db50>,
#  u'clue': <gensim.models.keyedvectors.Vocab at 0x7f62444bb450>,
#  u'downtown': <gensim.models.keyedvectors.Vocab at 0x7f624447db90>,
#  u'everywhere': <gensim.models.keyedvectors.Vocab at 0x7f62444f9f50>,
#  u'effort': <gensim.models.keyedvectors.Vocab at 0x7f624445c0d0>,
#  u'behalf': <gensim.models.keyedvectors.Vocab at 0x7f62444f9f90>,
#  u'fly': <gensim.models.keyedvectors.Vocab at 0x7f624447dc10>,
#  u'migrants': <gensim.models.keyedvectors.Vocab at 0x7f62444bb490>,
#  u'Family': <gensim.models.keyedvectors.Vocab at 0x7f624443f290>,
#  u'car': <gensim.models.keyedvectors.Vocab at 0x7f62444bb4d0>,
#  u'pretend': <gensim.models.keyedvectors.Vocab at 0x7f62444ff090>,
#  u'flagship': <gensim.models.keyedvectors.Vocab at 0x7f624443f310>,
#  u'values': <gensim.models.keyedvectors.Vocab at 0x7f62444ff0d0>,
#  u'can': <gensim.models.keyedvectors.Vocab at 0x7f62444bb510>,
#  u'believed': <gensim.models.keyedvectors.Vocab at 0x7f62444ff110>,
#  u'Our': <gensim.models.keyedvectors.Vocab at 0x7f62444ff150>,
#  u'arrive': <gensim.models.keyedvectors.Vocab at 0x7f624447dcd0>,
#  u'admired': <gensim.models.keyedvectors.Vocab at 0x7f62444ff190>,
#  u'crazy': <gensim.models.keyedvectors.Vocab at 0x7f624447dd10>,
#  u'nursing': <gensim.models.keyedvectors.Vocab at 0x7f624443f350>,
#  u'figure': <gensim.models.keyedvectors.Vocab at 0x7f624443f390>,
#  u'confused': <gensim.models.keyedvectors.Vocab at 0x7f624445c710>,
#  u'agent': <gensim.models.keyedvectors.Vocab at 0x7f624447dd90>,
#  u'sample': <gensim.models.keyedvectors.Vocab at 0x7f624447ddd0>,
#  u'heard': <gensim.models.keyedvectors.Vocab at 0x7f62444bb5d0>,
#  u'dropped': <gensim.models.keyedvectors.Vocab at 0x7f62443dbe50>,
#  u'allowed': <gensim.models.keyedvectors.Vocab at 0x7f62444ff1d0>,
#  u'stole': <gensim.models.keyedvectors.Vocab at 0x7f62444ff210>,
#  u'Keck': <gensim.models.keyedvectors.Vocab at 0x7f62444bb610>,
#  u'piled': <gensim.models.keyedvectors.Vocab at 0x7f6244419e90>,
#  u'discussion': <gensim.models.keyedvectors.Vocab at 0x7f62444bb650>,
#  u'Who': <gensim.models.keyedvectors.Vocab at 0x7f62444ff250>,
#  u'write': <gensim.models.keyedvectors.Vocab at 0x7f62444bb690>,
#  u'Significant': <gensim.models.keyedvectors.Vocab at 0x7f62444ff290>,
#  u'Gail': <gensim.models.keyedvectors.Vocab at 0x7f62444bb6d0>,
#  u'tile': <gensim.models.keyedvectors.Vocab at 0x7f624447de10>,
#  u'plus': <gensim.models.keyedvectors.Vocab at 0x7f624443f450>,
#  u'speaks': <gensim.models.keyedvectors.Vocab at 0x7f624443f490>,
#  u'Why': <gensim.models.keyedvectors.Vocab at 0x7f62444ff2d0>,
#  u'economy': <gensim.models.keyedvectors.Vocab at 0x7f62444bb710>,
#  u'These': <gensim.models.keyedvectors.Vocab at 0x7f624443f250>,
#  u'cocktail': <gensim.models.keyedvectors.Vocab at 0x7f62443e0510>,
#  u'huge': <gensim.models.keyedvectors.Vocab at 0x7f624443f4d0>,
#  u'may': <gensim.models.keyedvectors.Vocab at 0x7f624447de50>,
#  u'Hamel': <gensim.models.keyedvectors.Vocab at 0x7f62444ff310>,
#  u'applications': <gensim.models.keyedvectors.Vocab at 0x7f62444ff350>,
#  u'membership': <gensim.models.keyedvectors.Vocab at 0x7f624447de90>,
#  u'birthday': <gensim.models.keyedvectors.Vocab at 0x7f62443e6a50>,
#  u'designed': <gensim.models.keyedvectors.Vocab at 0x7f624445cd90>,
#  u'Yale': <gensim.models.keyedvectors.Vocab at 0x7f624447df10>,
#  u'date': <gensim.models.keyedvectors.Vocab at 0x7f62444ff390>,
#  u'such': <gensim.models.keyedvectors.Vocab at 0x7f62444ff3d0>,
#  u'suck': <gensim.models.keyedvectors.Vocab at 0x7f62444ff410>,
#  u'employers': <gensim.models.keyedvectors.Vocab at 0x7f62444081d0>,
#  u'revealed': <gensim.models.keyedvectors.Vocab at 0x7f6244484690>,
#  u'grow': <gensim.models.keyedvectors.Vocab at 0x7f624447df50>,
#  u'man': <gensim.models.keyedvectors.Vocab at 0x7f624447df90>,
#  u'stress': <gensim.models.keyedvectors.Vocab at 0x7f62444ff450>,
#  u'natural': <gensim.models.keyedvectors.Vocab at 0x7f62444ff4d0>,
#  u'remember': <gensim.models.keyedvectors.Vocab at 0x7f62444bb810>,
#  u'conscious': <gensim.models.keyedvectors.Vocab at 0x7f62444ff510>,
#  u'whenever': <gensim.models.keyedvectors.Vocab at 0x7f62444bb850>,
#  u'maybe': <gensim.models.keyedvectors.Vocab at 0x7f624447dfd0>,
#  u'provide': <gensim.models.keyedvectors.Vocab at 0x7f6244483050>,
#  u'so': <gensim.models.keyedvectors.Vocab at 0x7f62444ff550>,
#  u'silence': <gensim.models.keyedvectors.Vocab at 0x7f62444830d0>,
#  u'tall': <gensim.models.keyedvectors.Vocab at 0x7f6244483110>,
#  u'pulled': <gensim.models.keyedvectors.Vocab at 0x7f62444ff590>,
#  u'talk': <gensim.models.keyedvectors.Vocab at 0x7f6244483150>,
#  u'cute': <gensim.models.keyedvectors.Vocab at 0x7f6244483190>,
#  u'shoes': <gensim.models.keyedvectors.Vocab at 0x7f62444831d0>,
#  u'transplants': <gensim.models.keyedvectors.Vocab at 0x7f62444ff5d0>,
#  u'constituents': <gensim.models.keyedvectors.Vocab at 0x7f624443f510>,
#  u'midnight': <gensim.models.keyedvectors.Vocab at 0x7f62443e0c50>,
#  u'years': <gensim.models.keyedvectors.Vocab at 0x7f62444ff610>,
#  u'professors': <gensim.models.keyedvectors.Vocab at 0x7f62444ff650>,
#  u'brain': <gensim.models.keyedvectors.Vocab at 0x7f62444bb890>,
#  u'States': <gensim.models.keyedvectors.Vocab at 0x7f62443e6550>,
#  u'shake': <gensim.models.keyedvectors.Vocab at 0x7f6244483210>,
#  u'argued': <gensim.models.keyedvectors.Vocab at 0x7f6244483250>,
#  u'cold': <gensim.models.keyedvectors.Vocab at 0x7f62444bb8d0>,
#  u'still': <gensim.models.keyedvectors.Vocab at 0x7f62444bb910>,
#  u'clerkships': <gensim.models.keyedvectors.Vocab at 0x7f62444628d0>,
#  u'scale': <gensim.models.keyedvectors.Vocab at 0x7f6244419c10>,
#  u'police': <gensim.models.keyedvectors.Vocab at 0x7f624448f550>,
#  u'Greater': <gensim.models.keyedvectors.Vocab at 0x7f62444bb950>,
#  u'forms': <gensim.models.keyedvectors.Vocab at 0x7f62444bb990>,
#  u'window': <gensim.models.keyedvectors.Vocab at 0x7f62444bb9d0>,
#  u'offers': <gensim.models.keyedvectors.Vocab at 0x7f624443f5d0>,
#  u'policy': <gensim.models.keyedvectors.Vocab at 0x7f62444832d0>,
#  u'ours': <gensim.models.keyedvectors.Vocab at 0x7f6244462c10>,
#  u'main': <gensim.models.keyedvectors.Vocab at 0x7f6244483350>,
#  u'decades': <gensim.models.keyedvectors.Vocab at 0x7f62444ff690>,
#  u'abusive': <gensim.models.keyedvectors.Vocab at 0x7f6244419ed0>,
#  u'happened': <gensim.models.keyedvectors.Vocab at 0x7f624443f610>,
#  u'non': <gensim.models.keyedvectors.Vocab at 0x7f62444bba10>,
#  u'finance': <gensim.models.keyedvectors.Vocab at 0x7f6244483390>,
#  u'civilian': <gensim.models.keyedvectors.Vocab at 0x7f62444ff6d0>,
#  u'matches': <gensim.models.keyedvectors.Vocab at 0x7f62444ff710>,
#  u'underneath': <gensim.models.keyedvectors.Vocab at 0x7f624443f650>,
#  u'answer': <gensim.models.keyedvectors.Vocab at 0x7f624446d890>,
#  u'qualified': <gensim.models.keyedvectors.Vocab at 0x7f624443f690>,
#  u'She': <gensim.models.keyedvectors.Vocab at 0x7f6244483450>,
#  u'half': <gensim.models.keyedvectors.Vocab at 0x7f62444bba50>,
#  u'not': <gensim.models.keyedvectors.Vocab at 0x7f62444bba90>,
#  u'now': <gensim.models.keyedvectors.Vocab at 0x7f62444bbad0>,
#  u'killed': <gensim.models.keyedvectors.Vocab at 0x7f6244467110>,
#  u'nor': <gensim.models.keyedvectors.Vocab at 0x7f62444bbb10>,
#  u'term': <gensim.models.keyedvectors.Vocab at 0x7f624443f6d0>,
#  u'name': <gensim.models.keyedvectors.Vocab at 0x7f624443f710>,
#  u'lies': <gensim.models.keyedvectors.Vocab at 0x7f6244478d90>,
#  u'drop': <gensim.models.keyedvectors.Vocab at 0x7f62444bbb90>,
#  u'obsession': <gensim.models.keyedvectors.Vocab at 0x7f624443f810>,
#  u'debating': <gensim.models.keyedvectors.Vocab at 0x7f624443f790>,
#  u'rock': <gensim.models.keyedvectors.Vocab at 0x7f6244483490>,
#  u'instability': <gensim.models.keyedvectors.Vocab at 0x7f62444ff7d0>,
#  u'entirely': <gensim.models.keyedvectors.Vocab at 0x7f62444bbbd0>,
#  u'Zealand': <gensim.models.keyedvectors.Vocab at 0x7f62444abd90>,
#  u'r': <gensim.models.keyedvectors.Vocab at 0x7f62444ff810>,
#  u'fired': <gensim.models.keyedvectors.Vocab at 0x7f62444bbc50>,
#  u'badly': <gensim.models.keyedvectors.Vocab at 0x7f624442f290>,
#  u'abysmal': <gensim.models.keyedvectors.Vocab at 0x7f624443a590>,
#  u'challenges': <gensim.models.keyedvectors.Vocab at 0x7f62444bbc90>,
#  u'begun': <gensim.models.keyedvectors.Vocab at 0x7f624443f7d0>,
#  u'year': <gensim.models.keyedvectors.Vocab at 0x7f62444bbcd0>,
#  u'okay': <gensim.models.keyedvectors.Vocab at 0x7f62443d0490>,
#  u'happen': <gensim.models.keyedvectors.Vocab at 0x7f62444bbd10>,
#  u'avoided': <gensim.models.keyedvectors.Vocab at 0x7f62444bbd50>,
#  u'Dillman': <gensim.models.keyedvectors.Vocab at 0x7f62444bbd90>,
#  u'Carolina': <gensim.models.keyedvectors.Vocab at 0x7f62444bbdd0>,
#  u'Ken': <gensim.models.keyedvectors.Vocab at 0x7f6244467bd0>,
#  u'shown': <gensim.models.keyedvectors.Vocab at 0x7f62444bbe10>,
#  u'accomplish': <gensim.models.keyedvectors.Vocab at 0x7f62443eb050>,
#  u'Elizabeth': <gensim.models.keyedvectors.Vocab at 0x7f62444ff850>,
#  u'space': <gensim.models.keyedvectors.Vocab at 0x7f62444bbe90>,
#  ...}

# %%
#save model, when done training. To make use of it load it from memory.
if not os.path.exists("trained"):
    os.makedirs("trained")
vance2vec.save(os.path.join("trained", "vance2vec.w2v"))

# %%
#load model from memory as told above.
vance2vec = w2v.Word2Vec.load(os.path.join("trained", "vance2vec.w2v"))

# %%
#squash dimensionality to 2
#https://www.oreilly.com/learning/an-illustrated-introduction-to-the-t-sne-algorithm
#tsne (t stochastic distributed neighbour embedding) : helps in converting the 250 D word vector in to a 2 D vector, it squashes the 250 D vector in to a 2 D vector.
#So that we can plot and view it
#You can also you Principal Component analysis which uses Singular Value Decomposition which is a generalization of eigendecomposition.
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
#put it all into a giant matrix
all_word_vectors_matrix = vance2vec.wv.syn0

# %%
#train t sne on 250 D vector
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
#plot point in 2d space, tsne not only squashes the 250 D vector in to a 2 D vector but also gives us the X,Y coordinates.
points = pd.DataFrame(
    [(word, coords[0], coords[1]) #for each word, coords[0] - x and coords [1] - y
        for word, coords in [(word, all_word_vectors_matrix_2d[vance2vec.wv.vocab[word].index])for word in vance2vec.wv.vocab]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#       word         x          y
# 0   Preble -7.143142  -6.731486
# 1   yellow  5.074415   6.931360
# 2     four  4.784101  -2.388078
# 3    sleep -0.646919   7.719352
# 4  hanging -2.767090   4.926879
# 5  mansion  9.647242  10.533927
# 6   oldest -7.962599  -2.598339
# 7    saved -3.441164   9.402968
# 8    Until -2.830950  -8.879527
# 9   poorly -6.724362   2.427103

# %%
#plot
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))
#savefig('foo.png', bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#here we zoom in to our 2937 vocab list and plot a graph of only some particular points not of whole corpus, which helps us in analysing the relation between the words as well accuray of our model.
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(20, 20))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
 plot_region(x_bounds=(4.0, 8.0), y_bounds=(-5.0, -0.1))
 #savefig('foo.png', bbox_inches='tight')

# %%
#here we plot the other region and similarly we can continue doing that to analyse our words in a 2 D space.
plot_region(x_bounds=(-8, -6), y_bounds=(0, 2))

# %%
#distance, similarity, and ranking
#here we use cosine similarity in which given 2 vectors we can do dot product divided by the magnitude of the vectors.
# which gives the relation like X is related to Y as B to A. It calculates the distance between X and Y and checks which is the similar distance to word A and gives B as output.
# we can also use Gaussian Similarity.
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = vance2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("behavior", "discovered", "luck")
nearest_similarity_cosmul("join", "behavior", "wine")
# Out:
# behavior is related to discovered, as join is related to luck
# join is related to behavior, as buy is related to wine
# u'buy'

# %%
#here we print all those words which are closest to the word behavior in our corpus.
#similarly we can do this for other words as well.
vance2vec.most_similar("behavior")
# Out:
# [(u'discovered', 0.9996786117553711),
#  (u'luck', 0.9996746778488159),
#  (u'escaped', 0.9996725916862488),
#  (u'join', 0.9996396899223328),
#  (u'outbursts', 0.9996377825737),
#  (u'besides', 0.9996333718299866),
#  (u'resented', 0.9996326565742493),
#  (u'confirmed', 0.9996284246444702),
#  (u'possible', 0.9996159672737122),
#  (u'abandoned', 0.9996116757392883)]

# %%
#this is the 250 D vector of a word "buddy" if you all remember I had used num_features as 250, hence my word vector is a 250 D vector.
vance2vec["buddy"]
# Out:
# array([ 0.00732826,  0.08045617, -0.02780399, -0.00628558, -0.08971362,
#         0.021364  , -0.10642652, -0.00910826,  0.10571503,  0.09658644,
#         0.00507233, -0.12170361, -0.08369555,  0.06931379,  0.06371297,
#         0.1415377 , -0.11636707, -0.050169  ,  0.0172775 , -0.06573569,
#        -0.08889465, -0.04446552,  0.10374736,  0.09466445,  0.09004969,
#        -0.00183887, -0.04648966,  0.05312446, -0.08857759, -0.10370466,
#        -0.19999348,  0.08111575, -0.07638516, -0.12125251,  0.06351001,
#         0.13581271, -0.08935869,  0.18137616,  0.08340841, -0.02233252,
#        -0.13122866,  0.07520718, -0.07717101, -0.04330318, -0.06828906,
#        -0.10260015,  0.06868304,  0.01115204,  0.03073258,  0.04731694,
#         0.14389935, -0.01214861, -0.02022189,  0.00513931, -0.07692604,
#        -0.03142437,  0.10909666, -0.03152272, -0.11608743, -0.04884711,
#        -0.05619696,  0.01899577,  0.13164325, -0.11958093,  0.0881418 ,
#        -0.04616117, -0.09143205,  0.07678382,  0.19189356,  0.0366843 ,
#        -0.13424225,  0.03714158, -0.11700922,  0.06483915, -0.07786373,
#        -0.03819905,  0.03233363, -0.01919407,  0.08356658,  0.17381535,
#        -0.0972782 ,  0.05759337,  0.05387677, -0.03560492, -0.00112659,
#        -0.07218076, -0.14704563,  0.00240704,  0.22359698, -0.0191084 ,
#        -0.13377161,  0.05202073, -0.02517329,  0.11920878, -0.11367296,
#        -0.04225932,  0.04372814,  0.11874608, -0.1011558 , -0.12433004,
#        -0.01175859,  0.11000893,  0.00331089,  0.06646343,  0.02926276,
#        -0.12335372, -0.02030958,  0.00854355, -0.15538926, -0.11528202,
#        -0.14998685, -0.0271148 ,  0.04475491, -0.08448837,  0.10173445,
#        -0.13059585, -0.09382463, -0.03351318, -0.02993527,  0.16169602,
#         0.02546571, -0.01029156, -0.03748479, -0.0259549 ,  0.0174365 ,
#         0.01395218, -0.13027087, -0.00041581,  0.043201  , -0.05100862,
#        -0.08109343,  0.05654076,  0.04530853, -0.01904595, -0.08448049,
#         0.01800857, -0.08847908, -0.13554601, -0.00946209,  0.00363747,
#         0.02756138,  0.01494116,  0.16511112, -0.02888486,  0.10349679,
#         0.12963091, -0.08023105,  0.16165449,  0.13875979, -0.08716453,
#         0.0088888 ,  0.01863905, -0.03309808,  0.03470114,  0.02015754,
#         0.06986713, -0.06368094, -0.05623092,  0.00151945,  0.00621698,
#        -0.03938092,  0.08735698, -0.05320713, -0.1403715 ,  0.05559308,
#         0.0744673 , -0.11530477,  0.16845901,  0.10528019,  0.0613865 ,
#        -0.12474875,  0.01761181,  0.06599519, -0.0397673 ,  0.18519248,
#         0.00746881,  0.06168866, -0.07131828,  0.07670745, -0.04276689,
#         0.01220838,  0.00827664, -0.04951186,  0.04513333,  0.01450389,
#        -0.06751544, -0.01894571,  0.02219408,  0.09629515,  0.0744364 ,
#         0.07765382,  0.00070235,  0.01701291, -0.02354056,  0.04454329,
#         0.14477025, -0.10175877, -0.03864486, -0.02169883, -0.032485  ,
#         0.08216873,  0.0235916 , -0.0613078 , -0.14528079,  0.063889  ,
#         0.06072647,  0.02775577, -0.06193509, -0.08380819,  0.07804465,
#        -0.04350531, -0.02354858, -0.02095899, -0.01316525,  0.07161652,
#        -0.0111329 , -0.01011709,  0.03947662,  0.10747555,  0.06078105,
#         0.10440934,  0.0189522 , -0.02335128, -0.05777683, -0.01669952,
#        -0.0810137 , -0.02086643, -0.0103879 , -0.05102865, -0.14822048,
#         0.01206893,  0.15225941,  0.02738061, -0.09590915, -0.00430662,
#         0.03533468, -0.0219642 , -0.20476338, -0.01260071,  0.10346632,
#         0.13663781, -0.09702907,  0.11295174,  0.05413699,  0.02898415,
#         0.06853668, -0.03976143,  0.20040588,  0.10099474, -0.09236506], dtype=float32)
